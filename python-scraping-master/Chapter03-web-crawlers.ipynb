# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com/
# #cite_note-1
# #cite_note-actor-2
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-3
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-4
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-5
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Personal_life
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Awards_and_nominations
# #Filmography
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-2
# #cite_note-actor-2
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-6
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-7
# /wiki/Glory_Van_Scott
# #cite_note-walk-5
# #cite_note-bacon-6
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-8
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-6
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-9
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-10
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-11
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-12
# /wiki/Footloose_(1984_film)
# #cite_note-bio-10
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-13
# #cite_note-bacon-6
# #cite_note-14
# #cite_note-15
# /wiki/People_(American_magazine)
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-10
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-16
# /wiki/Tremors_(film)
# #cite_note-17
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-10
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said
# #cite_note-bio-10
# /wiki/The_New_York_Times
# #cite_note-nyt94-18
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-19
# /wiki/A_Few_Good_Men_(film)
# #cite_note-20
# /wiki/Michael_Greif
# #cite_note-bio-10
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-10
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-10
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-21
# /wiki/Sleepers_(film)
# #cite_note-22
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-10
# /wiki/Losing_Chase
# #cite_note-austin-23
# /wiki/Digging_to_China
# #cite_note-bio-10
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-10
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-24
# /wiki/File:KevinBaconTakingChanceFeb09.jpg
# /wiki/File:KevinBaconTakingChanceFeb09.jpg
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-25
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-26
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-27
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# #cite_note-28
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-29
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# #cite_note-30
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-31
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-32
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-33
# #cite_note-34
# /wiki/The_Following
# #cite_note-35
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-36
# /wiki/Huffington_Post
# #cite_note-37
# /wiki/Tremors_(film)
# /wiki/Wikipedia:Citation_needed
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# #cite_note-38
# #cite_note-39
# /wiki/Egg_as_food
# #cite_note-40
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-8
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-41
# /wiki/Tracy_Pollan
# #cite_note-42
# #cite_note-43
# #cite_note-44
# /wiki/The_Times
# #cite_note-45
# #cite_note-46
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernard_Madoff
# #cite_note-financialpost-47
# #cite_note-48
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-49
# #cite_note-50
# #cite_note-51
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# #cite_note-52
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# #cite_note-53
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-54
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# #cite_note-55
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Citing_sources
# /wiki/Wikipedia:Verifiability
# //en.wikipedia.org/w/index.php?title=Kevin_Bacon&action=edit
# /wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1
# /wiki/Wikipedia:Verifiability#Burden_of_evidence
# /wiki/Help:Maintenance_template_removal
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Broadcast_Film_Critics_Association_Awards
# /wiki/Broadcast_Film_Critics_Association_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/MTV_Movie_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics_Awards
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture_Drama
# /wiki/The_Woodsman_(2004_film)
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Awards
# /wiki/Beauty_Shop
# /wiki/Primetime_Emmy_Awards
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Miniseries_or_a_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Awards
# /wiki/X-Men:_First_Class
# /wiki/Saturn_Awards
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/People%27s_Choice_Awards
# /wiki/People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Saturn_Awards
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# #cite_note-56
# #cite_note-57
# #cite_note-58
# #cite_note-59
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_2-0
# #cite_ref-actor_2-1
# #cite_ref-actor_2-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-3
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-4
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_5-0
# #cite_ref-walk_5-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_6-0
# #cite_ref-bacon_6-1
# #cite_ref-bacon_6-2
# #cite_ref-bacon_6-3
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-7
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_8-0
# #cite_ref-cosmo91_8-1
# #cite_ref-9
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_10-0
# #cite_ref-bio_10-1
# #cite_ref-bio_10-2
# #cite_ref-bio_10-3
# #cite_ref-bio_10-4
# #cite_ref-bio_10-5
# #cite_ref-bio_10-6
# #cite_ref-bio_10-7
# #cite_ref-bio_10-8
# #cite_ref-bio_10-9
# #cite_ref-bio_10-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_11-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-12
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_13-0
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-14
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-15
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-16
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-17
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_18-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260&sec=&spon=&pagewanted=all
# #cite_ref-19
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-20
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-21
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-22
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_23-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-24
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-25
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-26
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-27
# https://archive.is/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-28
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-29
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-30
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-31
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_32-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_33-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# #cite_ref-34
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-35
# http://www.fox.com/the-following/
# #cite_ref-36
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-37
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-38
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-39
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-40
# http://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html?iid=HP_LN
# #cite_ref-41
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-42
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-43
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-44
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-45
# #cite_ref-46
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_47-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-48
# #cite_ref-49
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-50
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-51
# http://www.drawtheline.org/sign-now/
# #cite_ref-52
# http://www.sixdegrees.org/
# #cite_ref-53
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-54
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-55
# http://baconbros.com/
# #cite_ref-56
# /wiki/Reuters
# https://www.cbsnews.com/pictures/golden-globes-2018-highlights/50/
# /wiki/CBS_News
# #cite_ref-57
# https://www.theverge.com/2018/1/7/16861812/golden-globes-2018-aziz-ansari-master-of-none-best-actor-tv
# /wiki/The_Verge
# #cite_ref-58
# https://www.hollywoodreporter.com/news/aziz-ansari-wins-best-performance-by-an-actor-a-tv-series-comedy-musical-golden-globes-2018-1072154
# /wiki/The_Hollywood_Reporter
# #cite_ref-59
# http://www.indiewire.com/2018/01/aziz-ansari-wins-golden-globe-best-actor-tv-comedy-1201914235/
# /wiki/Indie_Wire
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.lortel.org/Archives/CreditableEntity/5597
# /wiki/Lortel_Archives
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /w/index.php?title=Template_talk:Kevin_Bacon&action=edit&redlink=1
# //en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/The_Closer
# /wiki/Wild_Things_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/The_Following
# /wiki/Cop_Car_(film)
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Kevin_Bacon_filmography
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# //en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Template:GoldenGlobeBestActorTVMiniseriesFilm
# /wiki/Template_talk:GoldenGlobeBestActorTVMiniseriesFilm
# //en.wikipedia.org/w/index.php?title=Template:GoldenGlobeBestActorTVMiniseriesFilm&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# //en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# //en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165
# https://www.worldcat.org/identities/containsVIAFID/39570812
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# /wiki/Biblioth%C3%A8que_nationale_de_France
# http://catalogue.bnf.fr/ark:/12148/cb139817766
# http://data.bnf.fr/ark:/12148/cb139817766
# /wiki/Integrated_Authority_File
# https://d-nb.info/gnd/124109659
# /wiki/International_Standard_Name_Identifier
# http://isni.org/isni/0000000121291300
# /wiki/Library_of_Congress_Control_Number
# http://id.loc.gov/authorities/names/n88034930
# /wiki/MusicBrainz
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/National_Library_of_the_Czech_Republic
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# /wiki/SNAC
# http://socialarchive.iath.virginia.edu/ark:/99166/w6w67gw2
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# https://www.idref.fr/084292652
# /wiki/Virtual_International_Authority_File
# https://viaf.org/viaf/39570812
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=856260815
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:Articles_with_hCards
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_January_2016
# /wiki/Category:Articles_needing_additional_references_from_October_2017
# /wiki/Category:All_articles_needing_additional_references
# /wiki/Category:Articles_with_IBDb_links
# /wiki/Category:Wikipedia_articles_with_BNE_identifiers
# /wiki/Category:Wikipedia_articles_with_BNF_identifiers
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_ISNI_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Wikipedia_articles_with_MusicBrainz_identifiers
# /wiki/Category:Wikipedia_articles_with_NKC_identifiers
# /wiki/Category:Wikipedia_articles_with_SNAC-ID_identifiers
# /wiki/Category:Wikipedia_articles_with_SUDOC_identifiers
# /wiki/Category:Wikipedia_articles_with_VIAF_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Portal:Contents
# /wiki/Portal:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# //shop.wikimedia.org
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=856260815
# /w/index.php?title=Kevin_Bacon&action=info
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=856260815
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=Kevin+Bacon
# /w/index.php?title=Special:ElectronPdf&page=Kevin+Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_B%C4%93kons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //wikimediafoundation.org/wiki/Terms_of_Use
# //wikimediafoundation.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://foundation.wikimedia.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# //www.mediawiki.org/

# %% [markdown]
# The a tag defines a hyperlink, which is used to link from one page to another.
#
# __The most important attribute of the a element is the href attribute, which indicates the link's destination.__
#
# By default, links will appear as follows in all browsers:
#
# - An unvisited link is underlined and blue
# - A visited link is underlined and purple
# - An active link is underlined and red

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re
#find all the link that lead to a content page.
html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')): #what is the specific 
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/People_(American_magazine)
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(film)
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# /wiki/Egg_as_food
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/The_Times
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernard_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Broadcast_Film_Critics_Association_Awards
# /wiki/Broadcast_Film_Critics_Association_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/MTV_Movie_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics_Awards
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture_Drama
# /wiki/The_Woodsman_(2004_film)
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Awards
# /wiki/Beauty_Shop
# /wiki/Primetime_Emmy_Awards
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Miniseries_or_a_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Awards
# /wiki/Saturn_Awards
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/People%27s_Choice_Awards
# /wiki/People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Saturn_Awards
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/Reuters
# /wiki/CBS_News
# /wiki/The_Verge
# /wiki/The_Hollywood_Reporter
# /wiki/Indie_Wire
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Lortel_Archives
# /wiki/AllMovie
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/The_Closer
# /wiki/Wild_Things_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/The_Following
# /wiki/Cop_Car_(film)
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Kevin_Bacon_filmography
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# /wiki/Biblioth%C3%A8que_nationale_de_France
# /wiki/Integrated_Authority_File
# /wiki/International_Standard_Name_Identifier
# /wiki/Library_of_Congress_Control_Number
# /wiki/MusicBrainz
# /wiki/National_Library_of_the_Czech_Republic
# /wiki/SNAC
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Virtual_International_Authority_File

# %% [markdown]
# The div tag defines a division or a section in an HTML document.
#
# The div element is often used as a container for other HTML elements to style them with CSS or to perform certain tasks with JavaScript.

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Robert_Duvall
# /wiki/Matthew_McConaughey
# /wiki/Robert_Duvall
# /wiki/Gods_and_Generals_(film)
# /wiki/Henry_Thomas_Harrison
# /wiki/Ira_W._Claflin
# /wiki/Alexander_Biddle
# /wiki/Robert_O._Tyler
# /wiki/Connecticut
# /wiki/Lower_house
# /wiki/National_Council_(Austria)
# /wiki/District_(Austria)
# /wiki/Departments_of_France
# /wiki/Corse-du-Sud
# /wiki/Sart%C3%A8ne
# /wiki/Granace
# /wiki/Communes_of_the_Corse-du-Sud_department
# /wiki/Arbori
# /wiki/Cargiaca
# /wiki/Cuttoli-Corticchiato
# /wiki/Cognocoli-Monticchi
# /wiki/Olmeto
# /wiki/Osani
# /wiki/Carbini
# /wiki/Sant%27Andr%C3%A9a-d%27Orcino
# /wiki/Grossa
# /wiki/Z%C3%A9vaco
# /wiki/Cantons_of_France
# /wiki/Cantons_of_the_Mayenne_department
# /wiki/Cantons_of_the_Tarn-et-Garonne_department
# /wiki/Cantons_of_the_Seine-Maritime_department
# /wiki/Cantons_of_Rouen
# /wiki/Geographic_coordinate_system
# /wiki/Mineralogy
# /wiki/Tridymite
# /wiki/New_York_Times
# /wiki/Broadsheet
# /wiki/The_Bakersfield_Californian
# /wiki/Payne_Award_for_Ethics_in_Journalism
# /wiki/The_Oregon_Experiment
# /wiki/Environmental_Philosophy_(journal)
# /wiki/The_Pioneer_Mother_(Eugene,_Oregon)
# /wiki/University_of_Oregon_Graduate_Teaching_Fellows_Federation
# /wiki/Board_of_Trustees_of_the_University_of_Oregon
# /wiki/Ethos_Magazine
# /wiki/Pacific_Northwest_Seismic_Network
# /wiki/Alaska
# /wiki/Bethel,_Alaska
# /wiki/Alaska
# /wiki/Juneau
# /wiki/Utqia%C4%A1vik,_Alaska
# /wiki/Poverty_threshold
# /wiki/Pen%27s_parade
# /wiki/Trachoma
# /wiki/Borrelia
# /wiki/Digital_object_identifier
# /wiki/Uniform_Resource_Name
# /wiki/Metadata
# /wiki/Operational_data_store
# /wiki/Sixth_normal_form
# /wiki/Data_mart
# /wiki/ROLAP
# /wiki/Dashboard_(business)
# /wiki/Slowly_changing_dimension
# /wiki/Sixth_normal_form
# /wiki/Spreadsheets
# /wiki/KCells
# /wiki/Calligra_Stage
# /wiki/Plasma_Active
# /wiki/Larswm
# /wiki/Motif_(software)
# /wiki/Repository_(version_control)
# /wiki/SVK
# /wiki/Branching_(version_control)
# /wiki/Rational_ClearCase
# /wiki/IBM_Software_Configuration_and_Library_Manager
# /wiki/AccuRev_SCM
# /wiki/Fossil_(software)
# /wiki/Kallithea_(software)
# /wiki/Revision_control
# /wiki/PVCS
# /wiki/Interleaved_deltas
# /wiki/GNU_Bazaar
# /wiki/Distributed_Concurrent_Versions_System
# /wiki/Veracity_(software)
# /wiki/Data_comparison
# /wiki/American_Inventors_Protection_Act
# /wiki/North_Carolina_Journal_of_Law_and_Technology
# /wiki/Law
# /wiki/Property_law
# /wiki/Criminal_procedure
# /wiki/Courts_of_Canada
# /wiki/Leader_of_the_Government_in_the_Senate_(Canada)
# /wiki/Walter_Morley_Aseltine
# /wiki/Bud_Olson
# /wiki/Alexander_Campbell_(Canadian_senator)
# /wiki/Esioff-L%C3%A9on_Patenaude
# /wiki/Tom_Siddon
# /wiki/Andrew_McNaughton
# /wiki/Commander_of_the_Canadian_Army
# /wiki/William_A._Milroy
# /wiki/Jim_Gervais
# /wiki/James_Howden_MacBrien
# /wiki/Canadian_Forces_Land_Force_Command
# /wiki/41_Canadian_Brigade_Group
# /wiki/Yellowknife
# /wiki/Tuktoyaktuk
# /wiki/Ekati_Diamond_Mine
# /wiki/Leinster,_Western_Australia
# /wiki/Zanthus,_Western_Australia
# /wiki/Eulaminna,_Western_Australia
# /wiki/Grass_Patch,_Western_Australia
# /wiki/Yarri,_Western_Australia
# /wiki/Shire_of_Menzies
# /wiki/Shire_of_Murchison
# /wiki/Sydney_Morning_Herald
# /wiki/Tabloid_(newspaper_format)
# /wiki/The_Times
# /wiki/Classic_FM_(UK)
# /wiki/Sky_Witness_(TV_channel)
# /wiki/Channel_Four_Television_Corporation
# /wiki/BBC_Radio_3
# /wiki/CE_London
# /wiki/Virgin_Media
# /wiki/Absolute_80s
# /wiki/NW_(magazine)
# /wiki/Absolute_Radio_70s
# /wiki/Absolute_Radio_90s
# /wiki/List_of_former_TV_channels_in_the_United_Kingdom
# /wiki/GOD_TV
# /wiki/Fox_Broadcasting_Company
# /wiki/IPTV
# /wiki/Claro_Puerto_Rico
# /wiki/Terrestrial_television
# /wiki/Communications_satellite#History
# /wiki/Ascension_Island
# /wiki/Union_of_South_Africa
# /wiki/Tar_Baby_Option
# /wiki/Afrikaner_nationalism
# /wiki/Genootskap_van_Regte_Afrikaners
# /wiki/South_African_apartheid_referendum,_1992
# /wiki/Steve_Biko
# /wiki/Black_Panther_Party
# /wiki/Huey_P._Newton
# /wiki/Robert_Hillary_King
# /wiki/Brandon_Darby
# /wiki/Riot_shields
# /wiki/The_Washington_Post
# /wiki/Federal_government_of_the_United_States
# /wiki/Diversity_jurisdiction
# /wiki/In_personam
# /wiki/Property
# /wiki/International_Standard_Book_Number
# /wiki/ISO_55000
# /wiki/ISO/IEC_15504
# /wiki/HTML
# /wiki/IEC_62379
# /wiki/ISO/IEC_15693
# /wiki/ISO_9241
# /wiki/ISO_5776
# /wiki/IS-IS
# /wiki/Photographic_Activity_Test
# /wiki/X3D
# /wiki/ISO_3166-1
# /wiki/Film_speed
# /wiki/Longitudinal_redundancy_check
# /wiki/ISO_898
# /wiki/ISO_639-2
# /wiki/ISO/IEC_8859-10
# /wiki/Mac_OS_Devanagari_encoding
# /wiki/%E0%A5%A6
# /wiki/57_(number)
# /wiki/Passenger_57
# /wiki/Wayback_Machine
# /wiki/TVP_Polonia
# /wiki/TVP1
# /wiki/TVP_Historia
# /wiki/TVP3_Rzesz%C3%B3w
# /wiki/TVP2
# /wiki/TVP_Parlament
# /wiki/TVP_Polonia
# /wiki/Minister_of_Foreign_Affairs_of_the_Republic_of_Poland
# /wiki/Ministry_of_Foreign_Affairs_(Thailand)
# /wiki/King_Mongkut
# /wiki/Crown_Prince_of_Thailand
# /wiki/Thai_language
# /wiki/Ts%27%C3%BCn-Lao_language
# /wiki/Koho_language
# /wiki/T%C3%A0y_language
# /wiki/Tai_languages
# /wiki/Thailand
# /wiki/Malay_Peninsula
# /wiki/Anthony_Reid_(academic)
# /wiki/International_Standard_Book_Number
# /wiki/List_of_IEC_standards
# /wiki/ISO_639-5
# /wiki/Algonquian_languages
# /wiki/Mahican_language
# /wiki/Mohawk_nation
# /wiki/WFLY
# /wiki/WHDL
# /wiki/Power_rating
# /wiki/Oxford_University_Press
# /wiki/British_Library
# /wiki/Bevis_Marks_Synagogue
# /wiki/Moses_Montefiore
# /wiki/Canada
# /wiki/Canadian_dollar
# /wiki/List_of_Canadian_companies
# /wiki/Metro_Inc.
# /wiki/Quebec_City
# /wiki/Saint-Augustin-de-Desmaures
# /wiki/2000%E2%80%9306_municipal_reorganization_in_Quebec
# /wiki/C%C3%B4te_Saint-Luc
# /wiki/1_E%2B6_m%C2%B2
# /wiki/Basketball
# /wiki/Br%C3%A4nnboll
# /wiki/Deaf_basketball
# /wiki/Underwater_rugby
# /wiki/Corkball
# /wiki/Bat-and-ball_games
# /wiki/Kickball
# /wiki/Iomain
# /wiki/International_rules_football
# /wiki/Vitilla
# /wiki/Major_League_Baseball
# /wiki/Colorado_Rockies
# /wiki/Nolan_Arenado
# /wiki/2015_Colorado_Rockies_season
# /wiki/Huston_Street
# /wiki/1985_Major_League_Baseball_draft
# /wiki/Milwaukee_Brewers
# /wiki/Eric_Thames
# /wiki/Varsity_team
# /wiki/South_Africa
# /wiki/Spain
# /wiki/Country_code_top-level_domain
# /wiki/.il
# /wiki/.bs
# /wiki/.tt
# /wiki/.sc
# /wiki/.sa
# /wiki/Terrorism_in_Saudi_Arabia
# /wiki/Unitary_executive_theory
# /wiki/Commerce_Clause
# /wiki/United_States_Congress
# /wiki/Spanish_language_in_the_United_States
# /wiki/Southern_Tiwa_language
# /wiki/Ethnologue
# /wiki/Unclassified_languages
# /wiki/Uto-Aztecan_languages
# /wiki/Burushaski
# /wiki/Dameli_language
# /wiki/Bagri_language
# /wiki/Parthian_language
# /wiki/List_of_rulers_of_Parthian_sub-kingdoms
# /wiki/Polemon_I_of_Pontus
# /wiki/Dynamis_(Bosporan_queen)
# /wiki/Demetrius_the_Fair
# /wiki/Magas_of_Cyrene
# /wiki/Polemon_II_of_Pontus
# /wiki/Antiochus_IV_of_Commagene
# /wiki/Ariarathes_I_of_Cappadocia
# /wiki/Ariamnes
# /wiki/Satrap
# /wiki/Portuguese_language
# /wiki/Lusophony_Games
# /wiki/Athletics_at_the_Lusophony_Games
# /wiki/Athletics_at_the_2009_Lusophony_Games
# /wiki/Jo%C3%A3o_Pedro_Ferreira
# /wiki/2010_European_Athletics_Championships_%E2%80%93_Men%27s_400_metres_hurdles
# /wiki/United_Kingdom
# /wiki/Finland
# /wiki/Bibliography_of_Finland
# /wiki/Bibliography_of_Abkhazia
# /wiki/Digital_object_identifier
# /wiki/Common_Logic
# /wiki/ISO/IEC_8859-12
# /wiki/ISO_9660
# /wiki/Antimagnetic_watch
# /wiki/ISO_31-4
# /wiki/ISO_80000-5
# /wiki/ISO_20400
# /wiki/ISO_3166
# /wiki/ZIP_Code
# /wiki/United_States_Census_Bureau
# /wiki/Oregon_Country
# /wiki/Realm_of_New_Zealand
# /wiki/Pitcairn_Supreme_Court
# /wiki/Pitcairn_Islands
# /wiki/Government_of_the_United_Kingdom
# /wiki/Succession_to_the_British_throne
# /wiki/President_of_Indonesia#Line_of_succession_and_impeachment
# /wiki/Joko_Widodo
# /wiki/Francois_Hollande
# /wiki/French_presidential_election,_2007
# /wiki/BBC
# /wiki/Dave_(TV_channel)
# /wiki/Classic_FM_(UK)
# /wiki/Bauer_Radio
# /wiki/KissFresh
# /wiki/Channel_4
# /wiki/Virgin_TV
# /wiki/Sound_Digital
# /wiki/List_of_years_in_British_television
# /wiki/BBC_Asian_Network
# /wiki/Film4oD
# /wiki/Jazz_FM_(UK)
# /wiki/Smooth_FM_100.4
# /wiki/Timeline_of_Global_Radio
# /wiki/Prince_Harry
# /wiki/The_Taking_of_Prince_Harry
# /wiki/Prince_Harry
# /wiki/The_London_Gazette
# /wiki/Charles_II_of_England
# /wiki/High_treason
# /wiki/Common_law
# /wiki/West_(publisher)
# /wiki/Northwest_Airlines
# /wiki/United_Airlines
# /wiki/Myanmar_Airways_International
# /wiki/Lufthansa_CityLine
# /wiki/Juneyao_Airlines
# /wiki/Cayman_Airways
# /wiki/AtlasGlobal
# /wiki/Bombardier_CRJ900
# /wiki/Learjet_60
# /wiki/Pratt_%26_Whitney_Canada_PW300
# /wiki/IAI_Galaxy
# /wiki/IAI_I-View
# /wiki/IAI_Lavi
# /wiki/International_Standard_Book_Number
# /wiki/XML_Metadata_Interchange
# /wiki/Romanization_of_Georgian
# /wiki/Romanization_of_Japanese
# /wiki/JSTOR
# /wiki/XML
# /wiki/Action_Message_Format
# /wiki/Integrated_development_environment
# /wiki/IntelliJ_IDEA
# /wiki/KDevelop
# /wiki/Text_editor
# /wiki/Syntax_highlighting
# /wiki/Syntax_error
# /wiki/Computer_programming
# /wiki/Edsger_W._Dijkstra
# /wiki/Living_systems
# /wiki/Social_environment
# /wiki/Family_therapy
# /wiki/Jay_Haley
# /wiki/Structural_Family_Therapy
# /wiki/International_Standard_Book_Number
# /wiki/Bestseller
# /wiki/Retailer
# /wiki/Angola
# /wiki/History_of_the_African_Union
# /wiki/Peace_and_Security_Council
# /wiki/African_Union
# /wiki/Great_power
# /wiki/William_Thornton_Rickert_Fox
# /wiki/American_Political_Science_Association
# /wiki/Charles_O._Jones
# /wiki/Jesse_Macy
# /wiki/Ph.D.
# /wiki/Scuola_Normale_Superiore_di_Pisa
# /wiki/Palazzo_della_Carovana
# /wiki/San_Piero_a_Grado
# /wiki/Architectural_style
# /wiki/International_Standard_Book_Number
# /wiki/EPUB
# /wiki/Microsoft
# /wiki/International_Standard_Serial_Number
# /wiki/ISO_2145
# /wiki/ISO_3977
# /wiki/ISO_19115
# /wiki/ISO/TC_211
# /wiki/Web_Feature_Service
# /wiki/SOAP
# /wiki/W3C_Device_Description_Working_Group
# /wiki/Extensible_Forms_Description_Language
# /wiki/XHTML%2BSMIL
# /wiki/Resource_Description_Framework
# /wiki/SPARQL
# /wiki/World_Wide_Web
# /wiki/Les_Horribles_Cernettes
# /wiki/Filk_music
# /wiki/Russian_science_fiction_and_fantasy
# /wiki/Robert_A._Heinlein_Award
# /wiki/The_Star_Beast
# /wiki/Charles_Scribner%27s_Sons
# /wiki/S._S._Van_Dine
# /wiki/Santa_Monica,_California
# /wiki/West_Los_Angeles
# /wiki/Little_Ethiopia,_Los_Angeles
# /wiki/Northeast_Los_Angeles
# /wiki/Mapping_L.A.
# /wiki/Unincorporated_area
# /wiki/Puerto_Rico
# /wiki/Native_Americans_in_the_United_States
# /wiki/Native_American_self-determination
# /wiki/Ada_Deer
# /wiki/Wayne_Aspinall
# /wiki/Thomas_Corwin
# /wiki/Samuel_McKee_(1774)
# /wiki/Jeremiah_Morrow
# /wiki/Ethan_Allen_Brown
# /wiki/W._A._Greenlund
# /wiki/Andrew_Hickenlooper
# /wiki/Jim_Rhodes
# /wiki/Political_Graveyard
# /wiki/Mark_Leibovich
# /wiki/New_York_Times
# /wiki/New_York_World-Telegram
# /wiki/KZKC-LP
# /wiki/WKBW-TV
# /wiki/PBS_Kids
# /wiki/Toonturama
# /wiki/Disney_Junior
# /wiki/SDTV
# /wiki/Progressive_scan
# /wiki/576p
# /wiki/NTSC
# /wiki/SMPTE_2059
# /wiki/Audio_Engineering_Society
# /wiki/Orchestration
# /wiki/Concert_band
# /wiki/Basso_continuo
# /wiki/Electric_bass
# /wiki/String_(music)
# /wiki/Albert_Augustine_Strings
# /wiki/Commission_(art)
# /wiki/Visual_arts
# /wiki/Website
# /wiki/Java_Servlets
# /wiki/W3C_Geolocation_API
# /wiki/Mobile_phone_tracking
# /wiki/United_States_Supreme_Court
# /wiki/Stephen_Breyer
# /wiki/Sonia_Sotomayor
# /wiki/Assistant_district_attorney
# /wiki/Crown_prosecutor
# /wiki/Crown_Prosecution_Service
# /wiki/National_security
# /wiki/Oil_well
# /wiki/Bamboo
# /wiki/List_of_bamboo_species
# /wiki/Nomex
# /wiki/Wildfire_suppression
# /wiki/Fire_control
# /wiki/Fire_chief
# /wiki/Heat_detector
# /wiki/Airport_crash_tender
# /wiki/List_of_low-cost_airlines
# /wiki/List_of_touch-solution_manufacturers
# /wiki/List_of_railway_companies
# /wiki/Bremgarten-Dietikon-Bahn
# /wiki/Minimum_railway_curve_radius
# /wiki/Breather_switch
# /wiki/Roll_way
# /wiki/Station_clock
# /wiki/Motive_power_depot
# /wiki/Gauntlet_track
# /wiki/National_Tramway_Museum
# /wiki/High_Peak_Junction
# /wiki/Cromford_Mill
# /wiki/List_of_mills_in_the_Metropolitan_Borough_of_Oldham
# /wiki/George_Saxon_%26_Co
# /wiki/South_East_Lancashire_Provincial_Card_and_Blowing_Room_Operatives%27_Association
# /wiki/Nathaniel_Eckersley
# /wiki/Edward_VII_of_the_United_Kingdom
# /wiki/Granville_Leveson-Gower,_2nd_Earl_Granville
# /wiki/Pyotr_Andreyevich_Shuvalov
# /wiki/Russia
# /wiki/Yakutia%E2%80%93Khabarovsk%E2%80%93Vladivostok_pipeline
# /wiki/Petrol
# /wiki/Xylene
# /wiki/Toluene
# /wiki/Catechin
# /wiki/Allelopathy
# /wiki/Coral
# /wiki/El_Ni%C3%B1o_Southern_Oscillation
# /wiki/Bibcode
# /wiki/Check_digit
# /wiki/Casting_out_nines
# /wiki/Product_(mathematics)
# /wiki/Monoidal_category
# /wiki/Tannakian_category
# /wiki/Inverse_limit
# /wiki/Group_(mathematics)
# /wiki/Steven_Weinberg
# /wiki/George_Paget_Thomson
# /wiki/The_Franklin_Institute_Awards
# /wiki/Louis_E._Brus
# /wiki/Calvin_Quate
# /wiki/Patrick_Suppes
# /wiki/John_W._Backus
# /wiki/John_H._Van_Vleck
# /wiki/Alexei_Alexeyevich_Abrikosov
# /wiki/Quantum_electrodynamics
# /wiki/Dirac_equation
# /wiki/Minkowski_metric
# /wiki/Lema%C3%AEtre%E2%80%93Tolman_metric
# /wiki/Interior_Schwarzschild_metric
# /wiki/Henri_Poincar%C3%A9
# /wiki/Brouwer_fixed-point_theorem
# /wiki/Fixed-point_theorem
# /wiki/Function_(mathematics)
# /wiki/Continuous_function
# /wiki/Geometric_calculus
# /wiki/Chain_rule
# /wiki/Quadratic_variation
# /wiki/Mathematics
# /wiki/Islamic_mathematics
# /wiki/Hunayn_ibn_Ishaq
# /wiki/Isaac_Israeli_ben_Solomon
# /wiki/Toledo,_Spain
# /wiki/Madrid
# /wiki/National_Archaeological_Museum_(Madrid)
# /wiki/Madrid
# /wiki/Czech_Republic_in_the_Eurovision_Song_Contest
# /wiki/Melodi_Grand_Prix
# /wiki/Hold_On_Be_Strong
# /wiki/Spiral_(Arne_Bendiksen_song)
# /wiki/Sommer_i_Palma
# /wiki/Voi_Voi
# /wiki/Sami_people
# /wiki/Southern_Sami
# /wiki/Elative_case
# /wiki/Sublative_case
# /wiki/Absolutive_case
# /wiki/Terminative_case
# /wiki/Elative_case
# /wiki/Orientative_case
# /wiki/Apudessive_case
# /wiki/Adverbial_case
# /wiki/Ablative_case
# /wiki/Essive-modal_case
# /wiki/Prepositional_case
# /wiki/Scottish_Gaelic
# /wiki/International_Standard_Book_Number
# /wiki/PDF/X
# /wiki/EXPRESS_(data_modeling_language)
# /wiki/Open_Virtualization_Format
# /wiki/RPath
# /wiki/Windows_Server_2008
# /wiki/X86-64
# /wiki/MacOS
# /wiki/Apple_Inc.
# /wiki/IPhone
# /wiki/IPhone_4S
# /wiki/App_Store_(macOS)
# /wiki/Eddy_Cue
# /wiki/App_Store_(macOS)
# /wiki/Audio_MIDI_Setup
# /wiki/ITunes
# /wiki/Mac_OS_8
# /wiki/Power_Macintosh
# /wiki/Macintosh_128K
# /wiki/PowerBook_150
# /wiki/Apple_Interactive_Television_Box
# /wiki/StyleWriter
# /wiki/Canon_(company)
# /wiki/Oc%C3%A9
# /wiki/Chairman
# /wiki/Recess_(break)#Parliamentary_procedure
# /wiki/Table_(parliamentary_procedure)
# /wiki/Second_(parliamentary_procedure)
# /wiki/Call_of_the_house
# /wiki/Parliamentary_procedure
# /wiki/Committee#Commit_(motion)
# /wiki/Majority_of_the_entire_membership
# /wiki/Motion_(parliamentary_procedure)
# /wiki/Requests_and_inquiries#Request_for_information
# /wiki/Robert%27s_Rules_of_Order
# /wiki/Limit_or_extend_limits_of_debate
# /wiki/Postpone_indefinitely
# /wiki/Table_(parliamentary_procedure)
# /wiki/International_Standard_Book_Number
# /wiki/ISO/IEC_8859-5
# /wiki/UTF-32
# /wiki/UTF-5
# /wiki/UTF-32
# /wiki/LY1_encoding
# /wiki/Slash_(punctuation)
# /wiki/Python_(programming_language)
# /wiki/Pylons_project#Pyramid
# /wiki/Webware_for_Python
# /wiki/Pylons_project#Pylons_Framework
# /wiki/Platform_independent#Platform-independent_software
# /wiki/Xamarin
# /wiki/Harry_Shum
# /wiki/Microsoft_Egypt
# /wiki/SwiftKey
# /wiki/Proprietary_software
# /wiki/File_sharing
# /wiki/User_(system)
# /wiki/Use_error
# /wiki/Indian_Airlines_Flight_605
# /wiki/Wider%C3%B8e_Flight_839
# /wiki/Helikopter_Service_Flight_165
# /wiki/Pacific_Western_Airlines_Flight_314
# /wiki/United_Airlines_Flight_696
# /wiki/Korean_Air_Lines_Flight_902
# /wiki/Secret_Intelligence_Service
# /wiki/Oleg_Penkovsky
# /wiki/Aquarium_(Suvorov)
# /wiki/GRU
# /wiki/Security_and_Intelligence_Division
# /wiki/Foreign_Intelligence_Service_(Romania)
# /wiki/Constitution_of_Romania
# /wiki/Constitution_of_Kosovo
# /wiki/Kadri_Veseli
# /wiki/Incumbent
# /wiki/Campaign_finance
# /wiki/Candidate
# /wiki/Paper_candidate
# /wiki/Chris_Smith_(New_Jersey_politician)
# /wiki/Democratic_Caucus_of_the_United_States_House_of_Representatives
# /wiki/Taxing_and_Spending_Clause
# /wiki/Postal_Clause
# /wiki/United_States_postal_notes
# /wiki/Postal_worker
# /wiki/National_Alliance_of_Postal_and_Federal_Employees
# /wiki/United_States_postal_notes
# /wiki/Address_Management_System
# /wiki/ZIP_Code
# /wiki/Radio_station
# /wiki/Radiocommunication_service
# /wiki/Mobile-satellite_service
# /wiki/Maritime_mobile-satellite_service
# /wiki/Broadcasting-satellite_service
# /wiki/Shortwave_radio
# /wiki/High_frequency
# /wiki/Band_II
# /wiki/Band_I
# /wiki/Amplitude_modulation_signalling_system
# /wiki/International_broadcasting
# /wiki/Antonio_Meucci
# /wiki/Staten_Island
# /wiki/Plainfield,_New_Jersey
# /wiki/National_Register_of_Historic_Places_listings_in_Union_County,_New_Jersey
# /wiki/National_Register_of_Historic_Places_listings_in_Bergen_County,_New_Jersey
# /wiki/North_Arlington,_New_Jersey
# /wiki/Cresskill,_New_Jersey
# /wiki/Federal_Information_Processing_Standards
# /wiki/ISO_3166
# /wiki/ISO/IEC_11801
# /wiki/MPEG-H
# /wiki/GIF
# /wiki/Adaptive_Transform_Acoustic_Coding
# /wiki/Code-excited_linear_prediction
# /wiki/MPEG-LA
# /wiki/Toshiba
# /wiki/Daito_Trust_Construction
# /wiki/%C3%86ON_(company)
# /wiki/Matsui_Securities
# /wiki/Uny
# /wiki/China_Resources_Vanguard
# /wiki/Tesco_Lotus
# /wiki/Harris_%2B_Hoole
# /wiki/Walkabout_(pub_chain)
# /wiki/Upper_Crust_(restaurant_chain)
# /wiki/Red_Bull
# /wiki/People%27s_Republic_of_China
# /wiki/East_China_Sea
# /wiki/Balearic_Sea
# /wiki/Pitiusas
# /wiki/International_Standard_Book_Number
# /wiki/Fictional_book
# /wiki/Miniature_book
# /wiki/E._H._Shepard
# /wiki/Winnie_the_Pooh_and_the_Blustery_Day
# /wiki/Victory_Canteen
# /wiki/The_Tigger_Movie
# /wiki/The_Jungle_Book_(1967_film)
# /wiki/Adventures_of_Mowgli
# /wiki/Klara_Rumyanova
# /wiki/MusicBrainz
# /wiki/Acoustic_fingerprint
# /wiki/Audio_signal
# /wiki/Sound_engineer
# /wiki/Music
# /wiki/Heavy_metal_music
# /wiki/Electric_Light_Orchestra
# /wiki/Louis_Clark
# /wiki/Eldorado_(Electric_Light_Orchestra_album)
# /wiki/Flashback_(Electric_Light_Orchestra_album)
# /wiki/Live_at_Wembley_%2778
# /wiki/Light_Years,_The_Very_Best_of_Electric_Light_Orchestra
# /wiki/The_Light_Shines_On_Vol_2
# /wiki/Face_the_Music_(Electric_Light_Orchestra_album)
# /wiki/Reinhold_Mack
# /wiki/Hot_Space
# /wiki/Queen_%2B_Paul_Rodgers_Tour
# /wiki/Magic_Tour_(Queen)
# /wiki/Live_Killers
# /wiki/Larry_Lurex
# /wiki/Hot_Space
# /wiki/Roger_Taylor_(Queen_drummer)
# /wiki/A_Day_at_the_Races_(album)
# /wiki/Mike_Grose
# /wiki/I_Want_to_Break_Free
# /wiki/Falsies
# /wiki/Petticoat
# /wiki/G-string
# /wiki/Variety_(magazine)
# /wiki/For_Your_Consideration_(advertising)
# /wiki/Academy_of_Motion_Picture_Arts_and_Sciences
# /wiki/Richard_Barthelmess
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Records_management
# /wiki/International_Standard_Book_Number
# /wiki/Unified_Modeling_Language
# /wiki/Power_take-off
# /wiki/ISO_9000
# /wiki/ISO_14031
# /wiki/International_Standard_Text_Code
# /wiki/ISO_639-3
# /wiki/International_Standard_Recording_Code
# /wiki/ISO_31-7
# /wiki/ISO_1000
# /wiki/ISO/IEC_11404
# /wiki/IEC_61968
# /wiki/IEC_60870
# /wiki/ISO/IEC_9995
# /wiki/MPEG-7
# /wiki/MPEG-D
# /wiki/Ada_Semantic_Interface_Specification
# /wiki/ISO/IEC_TR_12182
# /wiki/ISO/IEC_JTC_1/SC_28
# /wiki/IEC_TC_25
# /wiki/ISO/IEC_JTC_1/SC_38
# /wiki/International_Electrotechnical_Commission
# /wiki/R._E._B._Crompton
# /wiki/Royal_Society
# /wiki/List_of_Fellows_of_the_Royal_Society_elected_in_1919
# /wiki/List_of_Fellows_of_the_Royal_Society_M,N,O
# /wiki/James_Mansergh
# /wiki/Werribee
# /wiki/Mental_health_care
# /wiki/Mental_illness
# /wiki/Schizoaffective_disorder
# /wiki/Developmental_disability
# /wiki/Generalized_anxiety_disorder
# /wiki/Night_terror
# /wiki/Vascular_dementia
# /wiki/High-density_lipoprotein
# /wiki/Triglyceride
# /wiki/Calorie
# /wiki/KCAL_(disambiguation)
# /wiki/KCAL_(AM)
# /wiki/KVVZ
# /wiki/KSMC
# /wiki/KBKF-LP
# /wiki/KLVS
# /wiki/KKLB_(FM)
# /wiki/WMSJ
# /wiki/WBCI
# /wiki/WMEW
# /wiki/WRFR-LP
# /wiki/WUMF
# /wiki/WVOM-FM
# /wiki/FM_broadcasting
# /wiki/Harmonic
# /wiki/Tritone
# /wiki/Major_scale
# /wiki/Double_harmonic_scale
# /wiki/Chromatic_scale
# /wiki/Minor_scale
# /wiki/Jazz_minor_scale
# /wiki/International_Standard_Book_Number
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# /wiki/National_Library_of_the_Republic_of_Ireland
# /wiki/Leinster
# /wiki/County_Kerry
# /wiki/Ballinskelligs
# /wiki/Cloughaneely
# /wiki/Killea,_County_Donegal
# /wiki/Laghy
# /wiki/Carrigart
# /wiki/Owey_Island
# /wiki/Gortahork
# /wiki/The_Rosses
# /wiki/Machaire_Rabhartaigh
# /wiki/Ardagh,_County_Donegal
# /wiki/St._Johnston
# /wiki/Dowager
# /wiki/Widow
# /wiki/Death
# /wiki/Amoebozoan
# /wiki/Opisthokonta
# /wiki/Cryptomycota
# /wiki/Filasterea
# /wiki/Dermocystida
# /wiki/SAR_supergroup
# /wiki/Dinoflagellate
# /wiki/Radiolarians
# /wiki/Domain_(biology)
# /wiki/Systematics
# /wiki/Systematics_(disambiguation)
# /wiki/Systematics_-_study_of_multi-term_systems
# /wiki/General_systems_theory
# /wiki/Geomorphology
# /wiki/Bibcode
# /wiki/Digital_object_identifier
# /wiki/ISO_2788
# /wiki/Ruby_(programming_language)
# /wiki/Digital_rights_management
# /wiki/Rick_Falkvinge
# /wiki/Young_Pirate
# /wiki/Pirate_Party_Croatia
# /wiki/European_Pirate_Party
# /wiki/Parties_in_the_European_Council
# /wiki/European_People%27s_Party
# /wiki/Malta
# /wiki/Tal-Barrani
# /wiki/Tarxien
# /wiki/Gozo
# /wiki/Times_of_Malta
# /wiki/Gerald_Strickland,_1st_Baron_Strickland
# /wiki/St._Luke%27s_Hospital,_Malta
# /wiki/Poliomyelitis
# /wiki/Malaria
# /wiki/Flu
# /wiki/Influenza_A_virus_subtype_H1N1
# /wiki/Digital_object_identifier
# /wiki/Fiber_Distributed_Data_Interface
# /wiki/ISO_6943
# /wiki/ISO/IEC_8859-11
# /wiki/EBCDIC_322
# /wiki/EBCDIC_870
# /wiki/%C5%98
# /wiki/Czech_alphabet
# /wiki/Slavic_languages
# /wiki/Proto-Indo-European_religion
# /wiki/Sacrifice
# /wiki/Space_burial
# /wiki/Pluto
# /wiki/Local_Group
# /wiki/Pegasus_(constellation)
# /wiki/Cassiopeia_(constellation)
# /wiki/Sharmishtha
# /wiki/Ganesha
# /wiki/Lakshmi
# /wiki/Radha
# /wiki/Vaisakhi
# /wiki/Wolverhampton
# /wiki/List_of_Parliamentary_constituencies_in_West_Midlands
# /wiki/West_Bromwich_East_(UK_Parliament_constituency)
# /wiki/Labour_Party_(UK)
# /wiki/UK_Independence_Party
# /wiki/European_Parliament_election,_2014_(United_Kingdom)
# /wiki/Yorkshire_and_the_Humber_(European_Parliament_constituency)
# /wiki/York_(European_Parliament_constituency)
# /wiki/Netherlands_(European_Parliament_constituency)
# /wiki/European_Liberal_Democrat_and_Reform_Party_(European_Parliament_group)
# /wiki/Liberal_Democrats_(UK)
# /wiki/Liberalism_in_Honduras
# /wiki/Liberalism_in_Cuba
# /wiki/History_of_liberalism
# /wiki/Prime_Minister_of_Iran
# /wiki/Prime_Minister_of_the_Netherlands
# /wiki/First_Gerbrandy_cabinet
# /wiki/Ministry_of_Education,_Culture_and_Science_(Netherlands)
# /wiki/Science
# /wiki/Geologic_time_scale
# /wiki/Friedrich_Von_Alberti
# /wiki/Integrated_Authority_File
# /wiki/LIBRIS
# /wiki/International_Standard_Serial_Number
# /wiki/Language_Of_Temporal_Ordering_Specification
# /wiki/PDF/UA
# /wiki/HTML
# /wiki/ISO/IEC_18000
# /wiki/ANSI_escape_code
# /wiki/IEC_62351
# /wiki/Industrial_control_system
# /wiki/PROFIBUS
# /wiki/Ethernet_Powerlink
# /wiki/XPL_Protocol
# /wiki/Meter-Bus
# /wiki/Wireless_M-Bus
# /wiki/Higher_Speed_Ethernet
# /wiki/Small_form-factor_pluggable_transceiver#SFP+
# /wiki/Gigabit_interface_converter
# /wiki/AMP_Incorporated
# /wiki/Philadelphia_Business_Journal
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Ridley_Township,_Delaware_County,_Pennsylvania
# /wiki/Riddlewood,_Pennsylvania
# /wiki/Folsom,_Pennsylvania
# /wiki/Chester,_Pennsylvania
# /wiki/Wyoming_Valley
# /wiki/Paddy_Run
# /wiki/United_States_Geological_Survey
# /wiki/Biomedical_Advanced_Research_and_Development_Authority
# /wiki/Personal_protective_equipment
# /wiki/Bees
# /wiki/Stenotritidae
# /wiki/C._D._Michener
# /wiki/Annual_Review_of_Ecology_and_Systematics
# /wiki/Annual_Reviews_(publisher)
# /wiki/Annual_Review_of_Chemical_and_Biomolecular_Engineering
# /wiki/Engineering
# /wiki/Outline_of_industry
# /wiki/Construction_industry
# /wiki/Quantity_surveyor
# /wiki/Cost_engineering
# /wiki/Cost-plus_contract
# /wiki/Contract
# /wiki/Commonwealth_Law_Reports
# /wiki/United_States_Reports
# /wiki/United_States_Supreme_Court_Building
# /wiki/Martin_Luther_King_Jr._Memorial
# /wiki/Ruby_Hurley
# /wiki/Nonviolence
# /wiki/Christian_pacifism
# /wiki/Roland_Bainton
# /wiki/Kenneth_Scott_Latourette
# /wiki/Unequal_treaty
# /wiki/Most_favoured_nation
# /wiki/World_Trade_Organization_Ministerial_Conference_of_1999
# /wiki/Battle_in_Seattle
# /wiki/Rebecca_Solnit
# /wiki/International_Standard_Book_Number
# /wiki/ISO_10206
# /wiki/Turbo_Vision
# /wiki/Code_folding
# /wiki/EditPlus
# /wiki/Spell_checker
# /wiki/Instant_messaging
# /wiki/Pidgin_(software)
# /wiki/Open_source
# /wiki/The_Economist
# /wiki/Alain_de_Rothschild
# /wiki/Abbaye_des_Vaux_de_Cernay
# /wiki/Geographic_coordinate_system
# /wiki/Spatial_reference_system
# /wiki/ISO/IEC_80000
# /wiki/ISO_80000-1
# /wiki/ALGOL_60
# /wiki/Wayback_Machine
# /wiki/Simon_Schwartzman#Collected_texts_of_Simon_Schwartzman
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Library_science
# /wiki/Underrepresented_group
# /wiki/Minority_group
# /wiki/Ethnic_stereotype
# /wiki/Ethnic_identity_development
# /wiki/Erik_Erikson
# /wiki/Frances_FitzGerald_(journalist)
# /wiki/The_Wall_Street_Journal
# /wiki/Progressivism_in_the_United_States
# /wiki/Samuel_Gompers
# /wiki/Peter_J._McGuire
# /wiki/Maguire_(surname)
# /wiki/Ossianic_Society
# /wiki/Literary_society
# /wiki/Bengali_literature
# /wiki/Bishnupur,_Bankura
# /wiki/Sonamukhi
# /wiki/Draksharama
# /wiki/Dakor
# /wiki/List_of_districts_of_India
# /wiki/Gurdaspur_district
# /wiki/Regions_of_Punjab
# /wiki/Radio_Mirchi
# /wiki/The_Economic_Times
# /wiki/Mint_(newspaper)
# /wiki/The_Financial_Express_(India)
# /wiki/Udayavani
# /wiki/List_of_newspapers_in_India
# /wiki/Dainik_Jagran
# /wiki/The_Assam_Tribune
# /wiki/The_Financial_Express_(India)
# /wiki/Bengali_language
# /wiki/Chittagonian_language
# /wiki/Dogri_language
# /wiki/Writing_system
# /wiki/Old_Italic_alphabet
# /wiki/Ceri
# /wiki/Old_Testament
# /wiki/Book_of_Nahum
# /wiki/Books_of_Chronicles
# /wiki/Nevi%27im#Latter_Prophets
# /wiki/Joshua
# /wiki/Mordecai
# /wiki/Leah
# /wiki/Isaiah_in_rabbinic_literature
# /wiki/King_Manasseh
# /wiki/Jehu
# /wiki/Jehoram_of_Israel
# /wiki/Hebrew_language
# /wiki/Ablative_case
# /wiki/Comparative_case
# /wiki/Multiplicative_case
# /wiki/Formal_case
# /wiki/Direct_case
# /wiki/Partitive_case
# /wiki/Ablative_case
# /wiki/Morphosyntactic_alignment
# /wiki/Animacy
# /wiki/Yes_and_no
# /wiki/Echo_answer
# /wiki/International_Standard_Book_Number
# /wiki/Language_Of_Temporal_Ordering_Specification
# /wiki/Prolog
# /wiki/ISO_639-6
# /wiki/ISO_5
# /wiki/ISO_19439
# /wiki/ISO/IEC_8859-12
# /wiki/Extended_Unix_Code#EUC-TW
# /wiki/Code_page_668
# /wiki/EBCDIC_016
# /wiki/H
# /wiki/Sh_(digraph)
# /wiki/%D7%A9
# /wiki/Nun_(letter)
# /wiki/Maridi_Arabic
# /wiki/Judeo-Yemeni_Arabic
# /wiki/Syrian_Arabic
# /wiki/English_language
# /wiki/Digital_object_identifier
# /wiki/John_R._Levine
# /wiki/Javelin_Software
# /wiki/Bob_Frankston
# /wiki/Massachusetts_Institute_of_Technology
# /wiki/Oryol_State_University
# /wiki/Lahti_University_of_Applied_Sciences
# /wiki/Sheridan_College
# /wiki/Sound_stage
# /wiki/Film
# /wiki/Zoetrope
# /wiki/Zograscope
# /wiki/Camera_obscura
# /wiki/Geodesic_dome
# /wiki/Vastu_shastra
# /wiki/Algorithmic_art
# /wiki/Digital_art
# /wiki/Vincent_van_Gogh
# /wiki/Fontvieille,_Bouches-du-Rh%C3%B4ne
# /wiki/Mallemort
# /wiki/Peynier
# /wiki/Simiane-Collongue
# /wiki/Aurons
# /wiki/Saint-R%C3%A9my-de-Provence
# /wiki/Pierre_Daboval
# /wiki/Picasso
# /wiki/Les_Demoiselles_d%27Avignon
# /wiki/Armory_Show_of_1913
# /wiki/Henri_Matisse
# /wiki/Gouache
# /wiki/The_Walters_Art_Museum
# /wiki/Seal_of_Baltimore
# /wiki/Martin_State_Airport
# /wiki/College_Park_Airport
# /wiki/National_Register_of_Historic_Places_listings_in_Montgomery_County,_Maryland
# /wiki/Beall-Dawson_House
# /wiki/Bay_(architecture)
# /wiki/Plateresque
# /wiki/University_of_Alcal%C3%A1_de_Henares
# /wiki/Men%C3%A9ndez_Pelayo_International_University
# /wiki/Pedro_Salinas
# /wiki/International_Standard_Book_Number
# /wiki/ISO_690
# /wiki/Object_Constraint_Language
# /wiki/ISO_7002
# /wiki/ISO_31-7
# /wiki/ISO_639-3
# /wiki/ISO_31-0
# /wiki/ISO_31-8
# /wiki/ISO/IEC_8859-15
# /wiki/Acad%C3%A9mie_fran%C3%A7aise
# /wiki/List_of_members_of_the_Acad%C3%A9mie_fran%C3%A7aise#Seat_1
# /wiki/Val%C3%A9ry_Giscard_d%27Estaing
# /wiki/Georges_Pompidou
# /wiki/Ren%C3%A9_Pleven
# /wiki/Fr%C3%A9d%C3%A9ric_Fran%C3%A7ois-Marsal
# /wiki/Charles_Dupuy
# /wiki/Georges_Pompidou
# /wiki/Raymond_Poincar%C3%A9
# /wiki/Charles_Dupuy
# /wiki/Louis-Eug%C3%A8ne_Cavaignac
# /wiki/Alexandre_Ribot
# /wiki/Charles_Alexandre_de_Calonne
# /wiki/Coblenz
# /wiki/Mannheim
# /wiki/National_Theatre_Mannheim
# /wiki/Library_of_Congress_Control_Number
# /wiki/Library_catalog
# /wiki/WorldCat
# /wiki/Call_number
# /wiki/Library_of_Congress_Classification
# /wiki/Library_of_Congress_Classification#Class_Z_–_Bibliography,_Library_Science
# /wiki/Outline_of_Islam
# /wiki/Tawqi
# /wiki/Thuluth
# /wiki/Arabic_script_in_Unicode
# /wiki/Ugaritic_alphabet
# /wiki/Zapotec_script
# /wiki/Maldivian_writing_systems
# /wiki/Khom_script
# /wiki/Japanese_Braille
# /wiki/Deseret_alphabet
# /wiki/Computer_Braille_Code
# /wiki/%C2%A7
# /wiki/Slash_(punctuation)
# /wiki/Night-bombing
# /wiki/Bomber_escort
# /wiki/Interdictor
# /wiki/Air_interdiction
# /wiki/Military_helicopter
# /wiki/Sikorsky_S-61R
# /wiki/Bell_HSL
# /wiki/OCLC
# /wiki/National_Library_of_Australia
# /wiki/Reconciliation_Place
# /wiki/Native_title
# /wiki/Bioprospecting
# /wiki/Open_space_reserve
# /wiki/Food
# /wiki/Nonylphenol
# /wiki/Surfactant
# /wiki/Hypoxia_(medical)
# /wiki/Immersion_diuresis
# /wiki/Pulmonology
# /wiki/Hand_surgery
# /wiki/Singapore
# /wiki/Christmas_Island
# /wiki/Copyright_status_of_work_by_the_U.S._government
# /wiki/Edict_of_government
# /wiki/Reproduction_of_Federal_Law_Order
# /wiki/Official_text_copyright
# /wiki/Crown_copyright
# /wiki/Copyright
# /wiki/Postmark
# /wiki/Singapore_Post
# /wiki/Postal_codes_in_Singapore
# /wiki/Postal_codes_in_Egypt
# /wiki/Ethiopian%E2%80%93Egyptian_War
# /wiki/Khedivate_of_Egypt
# /wiki/Grand_vizier
# /wiki/List_of_Ottoman_Grand_Viziers
# /wiki/M%C3%BCtercim_Mehmed_R%C3%BC%C5%9Fdi_Pasha
# /wiki/Bayram_Pasha
# /wiki/K%C3%A2mil_Pasha
# /wiki/Bayburtlu_Kara_Ibrahim_Pasha
# /wiki/Had%C4%B1m_Mehmed_Pasha
# /wiki/Mehmed_Said_Pasha
# /wiki/Sultanzade_Mehmed_Pasha
# /wiki/Hekimo%C4%9Flu_Ali_Pasha
# /wiki/Ottoman_Empire
# /wiki/Caucasus
# /wiki/Gulf_of_Kutch
# /wiki/Ligurian_Sea
# /wiki/Aegean_Sea
# /wiki/List_of_kings_of_Macedonia
# /wiki/Belistiche
# /wiki/Chariot_racing
# /wiki/Homer
# /wiki/Agora
# /wiki/Pezhetairos
# /wiki/Sukhumi
# /wiki/Miletus
# /wiki/G%C3%B6zl%C3%BCkule
# /wiki/Xanthos
# /wiki/Syedra
# /wiki/Ancient_Mediterranean_piracy
# /wiki/Archaic_Greece
# /wiki/Pederasty_in_ancient_Greece
# /wiki/List_of_organizations_designated_by_the_Southern_Poverty_Law_Center_as_anti-LGBT_hate_groups
# /wiki/American_Vision
# /wiki/First_Amendment_to_the_United_States_Constitution
# /wiki/FEC_v._Massachusetts_Citizens_for_Life
# /wiki/Marcus_v._Search_Warrant
# /wiki/Minersville_School_District_v._Gobitis
# /wiki/Stanley_v._Georgia
# /wiki/Valentine_v._Chrestensen
# /wiki/Roth_v._United_States
# /wiki/Symbolic_speech
# /wiki/Florida_Star_v._B._J._F.
# /wiki/Nitke_v._Gonzales
# /wiki/Obscenity
# /wiki/Internet_censorship_and_surveillance_by_country
# /wiki/Censorship_in_Venezuela
# /wiki/Internet_in_Bangladesh#Internet_censorship_and_surveillance
# /wiki/Rape_during_the_Bangladesh_Liberation_War
# /wiki/Unacknowledged_rape
# /wiki/Rape_during_the_occupation_of_Germany
# /wiki/Military_history_of_Canada_during_World_War_II
# /wiki/Occupation_of_the_Baltic_states
# /wiki/Latvian_partisans
# /wiki/Mongolian_People%27s_Republic
# /wiki/Mongolian_language
# /wiki/International_Standard_Book_Number
# /wiki/Wayback_Machine
# /wiki/Terabyte
# /wiki/Kibibyte
# /wiki/IEEE_1541
# /wiki/Futurebus
# /wiki/PCI_eXtensions_for_Instrumentation
# /wiki/FASTBUS
# /wiki/Amiga_Zorro_III
# /wiki/Paula_(computer_chip)
# /wiki/Amiga_Ranger_Chipset
# /wiki/Copper_(OCS)
# /wiki/8-bit
# /wiki/Microcode
# /wiki/Chemical_computing
# /wiki/Image_processing
# /wiki/Digital_object_identifier
# /wiki/ISO_31-0
# /wiki/Richter_scale
# /wiki/Surface_wave_magnitude
# /wiki/Local_magnitude_scale
# /wiki/Foreshock
# /wiki/Earthquake_prediction
# /wiki/PubMed_Identifier
# /wiki/Tele-epidemiology
# /wiki/Meteosat
# /wiki/Sentinel-2B
# /wiki/Radarsat-2
# /wiki/SCISAT-1
# /wiki/Shaw_Direct
# /wiki/Galaxy_(Australian_television)
# /wiki/Showcase_(Australian_TV_channel)
# /wiki/The_West_Wing
# /wiki/Pedagogical
# /wiki/Education_in_Seychelles
# /wiki/Index_of_Seychelles-related_articles
# /wiki/Seychelles_at_the_2016_Summer_Olympics
# /wiki/Vanuatu_at_the_2016_Summer_Olympics
# /wiki/Australia_at_the_2016_Summer_Olympics
# /wiki/Rowing_at_the_2016_Summer_Olympics_%E2%80%93_Men%27s_coxless_pair
# /wiki/New_Zealand
# /wiki/Isle_of_Man
# /wiki/British%E2%80%93Irish_Intergovernmental_Conference
# /wiki/Ulster_Scots_people
# /wiki/Britons_in_Egypt
# /wiki/Anglo-Indian_people
# /wiki/International_Standard_Book_Number
# /wiki/Digital_object_identifier
# /wiki/ISO/IEC_9797-1
# /wiki/On-board_diagnostics
# /wiki/EXPRESS_(data_modeling_language)
# /wiki/Equal-loudness_contour
# /wiki/Film_speed
# /wiki/ISO_8501-1
# /wiki/ISO_14651
# /wiki/ISO_4031
# /wiki/ISO_1
# /wiki/ISO/IEEE_11073
# /wiki/Open_standard
# /wiki/Peter_Suber
# /wiki/Digital_object_identifier
# /wiki/ISO_217
# /wiki/ISO_639-5
# /wiki/ISO_8601
# /wiki/Anno_Domini
# /wiki/Yuga
# /wiki/Kali
# /wiki/Vachana_sahitya
# /wiki/Halmidi
# /wiki/Amazon_Standard_Identification_Number
# /wiki/Amazon_Virtual_Private_Cloud
# /wiki/Amazon_Redshift
# /wiki/AWS_Lambda
# /wiki/IMDb
# /wiki/Rating_scale
# /wiki/Major_depressive_disorder
# /wiki/Hippocrates
# /wiki/Messina
# /wiki/Luigi_Rizzo
# /wiki/Virtual_International_Authority_File
# /wiki/United_States
# /wiki/Beryllium
# /wiki/Reactive_nonmetal
# /wiki/Dubnium
# /wiki/Group_(periodic_table)
# /wiki/Trivial_name
# /wiki/La_Boh%C3%A8me
# /wiki/Xylophone
# /wiki/International_Standard_Book_Number
# /wiki/ISO_2014
# /wiki/ISO_10218
# /wiki/RM-ODP
# /wiki/Whirlpool_(hash_function)
# /wiki/Longitudinal_redundancy_check
# /wiki/ArmSCII
# /wiki/QR_code
# /wiki/ISO_14651
# /wiki/OSI_model
# /wiki/Data_Link_Control
# /wiki/JetDirect
# /wiki/Internet_Printing_Protocol
# /wiki/Novell
# /wiki/IPX/SPX
# /wiki/NWLink
# /wiki/NetBIOS
# /wiki/Novell_NetWare
# /wiki/File_Transfer_Protocol
# /wiki/HTML_editor
# /wiki/W3C
# /wiki/XQuery
# /wiki/O%27Reilly_Media
# /wiki/Web_2.0_Summit
# /wiki/Mark_Cuban
# /wiki/Dirk_Nowitzki
# /wiki/All-NBA_First_Team
# /wiki/Cleveland_Cavaliers
# /wiki/Larry_Nance
# /wiki/Michael_Jordan
# /wiki/Will_Perdue
# /wiki/Alistair_Cragg
# /wiki/Herschel_Walker
# /wiki/United_States_Secretary_of_Veterans_Affairs
# /wiki/David_Shulkin
# /wiki/United_States_Secretary_of_Defense
# /wiki/Under_Secretary_of_Defense_for_Policy
# /wiki/Maldives
# /wiki/Economy_of_Pakistan
# /wiki/Economy_of_Spain
# /wiki/List_of_newspapers_in_Spain
# /wiki/Girona
# /wiki/Biblioth%C3%A8que_nationale_de_France
# /wiki/Mus%C3%A9e_de_l%E2%80%99air_et_de_l%E2%80%99espace
# /wiki/%C3%89cole_Nationale_Sup%C3%A9rieure_des_Mines_de_Saint-%C3%89tienne
# /wiki/%C3%89cole_nationale_sup%C3%A9rieure_des_industries_chimiques_(ENSIC,_Nancy)
# /wiki/%C3%89cole_sup%C3%A9rieure_de_commerce_de_Pau
# /wiki/EDHEC_Business_School_(Ecole_des_Hautes_Etudes_Commerciales_du_Nord)
# /wiki/%C3%89cole_nationale_sup%C3%A9rieure_des_mines_de_Nancy
# /wiki/ICN_Graduate_Business_School
# /wiki/%C3%89cole_nationale_sup%C3%A9rieure_de_physique_de_Strasbourg
# /wiki/Mines_ParisTech
# /wiki/Tidjane_Thiam
# /wiki/Michel_Camdessus
# /wiki/Pierre-Paul_Schweitzer
# /wiki/M%C3%A9daille_de_la_R%C3%A9sistance
# /wiki/13th_Demi-Brigade_of_the_Foreign_Legion
# /wiki/Armored_car_(military)
# /wiki/International_Standard_Book_Number
# /wiki/Bibliotherapy
# /wiki/Drug_abuse
# /wiki/Depressant
# /wiki/Trazodone
# /wiki/Desmethylsertraline
# /wiki/Arylcyclohexylamine
# /wiki/Cypenamine
# /wiki/4-FA
# /wiki/SKF-81297
# /wiki/Perospirone
# /wiki/Betaxolol
# /wiki/ATC_code_S01#S01E
# /wiki/Povidone-iodine
# /wiki/Denatured_alcohol
# /wiki/Ethyl_acetate
# /wiki/Ethyl_acetate_(data_page)#Thermodynamic_properties
# /wiki/Dielectric_constant
# /wiki/Waveguide
# /wiki/SOFAR_channel
# /wiki/Bermuda
# /wiki/Palace_of_Whitehall
# /wiki/White_Lodge,_Richmond_Park
# /wiki/Geographic_coordinate_system
# /wiki/70th_parallel_south
# /wiki/Australia
# /wiki/Liberal_Party_of_Australia
# /wiki/Australian_Labor_Party_leadership_spill,_June_2013
# /wiki/Brian_Howe_(politician)
# /wiki/Bob_Hawke
# /wiki/University_of_South_Australia
# /wiki/Ian_Gould_(geologist)
# /wiki/South_Australian_Minerals_%26_Petroleum_Expert_Group
# /wiki/AusIMM
# /wiki/Australia
# /wiki/Indonesia
# /wiki/Solomon_Islands
# /wiki/International_Monetary_Fund
# /wiki/Balance_of_payments
# /wiki/The_Financial_Times
# /wiki/Neil_Kinnock
# /wiki/George_Thomson,_Baron_Thomson_of_Monifieth
# /wiki/Royal_Society_of_Edinburgh
# /wiki/Roger_Fletcher_(mathematician)
# /wiki/Peter_N._T._Wells
# /wiki/Eleanor_Dodson
# /wiki/Donald_Knuth
# /wiki/Alfred_Y._Cho
# /wiki/M._Frederick_Hawthorne
# /wiki/Digital_object_identifier
# /wiki/ISO_3166-1
# /wiki/ISO/IEC_9126
# /wiki/ISO_519
# /wiki/ISO/IEC_27000-series
# /wiki/C_Sharp_(programming_language)
# /wiki/Common_Language_Infrastructure
# /wiki/ISO_3166-3
# /wiki/Kyrgyzstan
# /wiki/Population_density
# /wiki/Milwaukee
# /wiki/Marcus_Amphitheater
# /wiki/Kohl_Center
# /wiki/WSUM
# /wiki/Megahertz
# /wiki/Atomic_units
# /wiki/Litre
# /wiki/SI_derived_unit
# /wiki/Ampere
# /wiki/International_System_of_Units
# /wiki/Micro-
# /wiki/Deci-
# /wiki/1000_(number)
# /wiki/Quaternary_numeral_system
# /wiki/Radix
# /wiki/Gujarati_numerals
# /wiki/Gujarati_journalism
# /wiki/Kheda
# /wiki/Deesa
# /wiki/Banaskantha_district
# /wiki/Government_of_Gujarat
# /wiki/Gujarati_cuisine
# /wiki/Saffron
# /wiki/Perampanel
# /wiki/LY-503430
# /wiki/ChemSpider
# /wiki/Royal_Institute_of_Chemistry
# /wiki/Burlington_House
# /wiki/Duke_of_Devonshire
# /wiki/Derbyshire
# /wiki/Derbyshire_lead_mining_history
# /wiki/Lead
# /wiki/Aluminium
# /wiki/Tempering_(metallurgy)
# /wiki/Yield_strength
# /wiki/Stress%E2%80%93strain_curve
# /wiki/Glass_fiber
# /wiki/Synthetic_fiber
# /wiki/Cellulose_acetate
# /wiki/Qiviut
# /wiki/Polyester
# /wiki/Tweed_(cloth)
# /wiki/Dimity
# /wiki/Textile
# /wiki/Gore-Tex
# /wiki/Glossary_of_textile_manufacturing
# /wiki/Knitting
# /wiki/Slip-stitch_knitting#Mosaic_knitting
# /wiki/Gauge_(knitting)
# /wiki/Basic_knitted_fabrics#Garter_stitch
# /wiki/Warp_knitting
# /wiki/List_of_knitting_stitches
# /wiki/Stitch_(textile_arts)
# /wiki/Weaving
# /wiki/Spinning_frame
# /wiki/Cardroom_Amalgamation
# /wiki/International_Standard_Book_Number
# /wiki/X3D
# /wiki/ISO_13490
# /wiki/StorNext_File_System
# /wiki/Transaction-Safe_FAT_File_System
# /wiki/USB
# /wiki/Intel_UltraPath_Interconnect
# /wiki/Amiga_Zorro_II
# /wiki/Amiga_2000
# /wiki/Professional_File_System
# /wiki/ReAction_GUI
# /wiki/Hollywood_(programming_language)
# /wiki/AmigaOne
# /wiki/Sam460ex#Sam460cr
# /wiki/Timberwolf_web_browser
# /wiki/Conkeror
# /wiki/NetFront
# /wiki/HTML5
# /wiki/Open_format
# /wiki/W3C
# /wiki/Speech_Synthesis_Markup_Language
# /wiki/XInclude
# /wiki/JavaScript_Style_Sheets
# /wiki/World_Wide_Web_Consortium
# /wiki/Web_browser
# /wiki/OmniWeb
# /wiki/Mac_OS_X_Tiger
# /wiki/IOS_5
# /wiki/IAd_Producer
# /wiki/IOS_version_history
# /wiki/IPhone_6S
# /wiki/Metaio
# /wiki/Craig_Federighi
# /wiki/WWDC_2014
# /wiki/Display_PostScript
# /wiki/Direct_Save_Protocol
# /wiki/RandR
# /wiki/KDE_Display_Manager
# /wiki/X_display_manager_(program_type)
# /wiki/X_terminal
# /wiki/Xcalc
# /wiki/AIGLX
# /wiki/XWayland
# /wiki/Fluxbox
# /wiki/GNUstep
# /wiki/Free_software
# /wiki/Proprietary_software
# /wiki/Obfuscated_code
# /wiki/Man-in-the-middle_attack
# /wiki/Data_loss_prevention_software
# /wiki/Keystroke_logging
# /wiki/Zombie_(computer_science)
# /wiki/Yahoo
# /wiki/The_New_York_Times
# /wiki/International_Standard_Serial_Number
# /wiki/ISO_9897
# /wiki/Preferred_number
# /wiki/ISO_639-2
# /wiki/Business_Process_Model_and_Notation
# /wiki/ISO_5964
# /wiki/ISO_15926
# /wiki/ISO_15924
# /wiki/110_film
# /wiki/Kodak
# /wiki/Zweigle%27s
# /wiki/Midtown_Plaza_(Rochester)
# /wiki/Powers_Building
# /wiki/Chili%E2%80%93West_Historic_District
# /wiki/High_Falls_Film_Festival
# /wiki/My_Architect
# /wiki/Louis_Kahn
# /wiki/Twenty-five_Year_Award
# /wiki/Fazlur_Rahman_Khan
# /wiki/Engineering_Legends
# /wiki/International_Standard_Book_Number
# /wiki/Open_Systems_Interconnection
# /wiki/ISO_22000
# /wiki/Simple_feature_access
# /wiki/CORBA
# /wiki/SDMX
# /wiki/ISO_9241
# /wiki/ISO/IEC_8859-11
# /wiki/ISO_2015
# /wiki/Shoe_size
# /wiki/Photographic_Activity_Test
# /wiki/ISO/IEC_4909
# /wiki/Preferred_number
# /wiki/Guidelines_for_the_Definition_of_Managed_Objects
# /wiki/International_Electrotechnical_Commission
# /wiki/Ukraine
# /wiki/Chernihiv
# /wiki/Lviv
# /wiki/Chapel_of_the_Boim_family
# /wiki/Forum_Lviv
# /wiki/St._George%27s_Cathedral,_Lviv
# /wiki/Virgin_Mary
# /wiki/List_of_Anglican_Church_calendars
# /wiki/Continuing_Anglican_movement
# /wiki/Anglican_Province_of_Christ_the_King
# /wiki/Church_of_England_(Continuing)
# /wiki/Stephen_C._Reber
# /wiki/Anglican_Catholic_Church_of_Canada
# /wiki/Peter_D._Robinson
# /wiki/Abortion
# /wiki/PubMed_Identifier
# /wiki/PubMed_Central
# /wiki/PDF
# /wiki/ISO_13406-2
# /wiki/Open_Document_Architecture
# /wiki/ISO_15926_WIP
# /wiki/ISO_80000-1
# /wiki/ISO_6438
# /wiki/Windows-1258
# /wiki/Code_page_1103
# /wiki/EBCDIC_013
# /wiki/Zapf_Dingbats#Encoding
# /wiki/%E2%9D%92
# /wiki/Typographic_ligature
# /wiki/%CA%A7
# /wiki/Nasal_consonant
# /wiki/Affricate_consonant
# /wiki/Voiceless_alveolar_lateral_affricate
# /wiki/Voiceless_velar_lateral_affricate
# /wiki/Voiceless_retroflex_lateral_fricative
# /wiki/Journal_of_the_International_Phonetic_Association
# /wiki/International_Standard_Serial_Number
# /wiki/ISO_8373
# /wiki/ISO_2848
# /wiki/PDF/VT
# /wiki/Legal_Entity_Identifier
# /wiki/ISO_7200
# /wiki/ISO/IEC_646
# /wiki/Prolog
# /wiki/MPEG-4_Part_2
# /wiki/International_Electrotechnical_Commission
# /wiki/Deutsche_Kommission_Elektrotechnik_Elektronik_Informationstechnik_im_DIN_und_VDE
# /wiki/CENELEC
# /wiki/Zigbee
# /wiki/Routing
# /wiki/Flood_search_routing
# /wiki/Subscriber
# /wiki/Pharmaceutical
# /wiki/Therapeutic_antibody
# /wiki/Regorafenib
# /wiki/EFNB2
# /wiki/Vandetanib
# /wiki/Cenegermin
# /wiki/Erlotinib
# /wiki/Afatinib
# /wiki/Placental_growth_factor
# /wiki/Radotinib
# /wiki/Cyclotraxin_B
# /wiki/Adrenomedullin
# /wiki/BNN-20
# /wiki/Neuroprotective_agent
# /wiki/Memantine
# /wiki/Piperazine
# /wiki/2C-T-8
# /wiki/MDA-19
# /wiki/HU-331
# /wiki/JWH-081
# /wiki/Diethyltryptamine
# /wiki/Ibogamine
# /wiki/Xorphanol
# /wiki/Bufotenin
# /wiki/Flumexadol
# /wiki/Vilazodone
# /wiki/Escitalopram
# /wiki/3-MeO-PCP
# /wiki/Isoflurane
# /wiki/SB-357134
# /wiki/Meta-Chlorophenylpiperazine
# /wiki/Oxaflozane
# /wiki/Idalopirdine
# /wiki/5-MeO-DET
# /wiki/LSD-Pip
# /wiki/Aripiprazole
# /wiki/Thioxanthene
# /wiki/Typical_antipsychotic
# /wiki/Melperone
# /wiki/Ephedrine
# /wiki/Trimethoxyamphetamine
# /wiki/Amoxapine
# /wiki/Zuclopenthixol
# /wiki/Moperone
# /wiki/Butaperazine
# /wiki/Chlorpromazine
# /wiki/Bromopride
# /wiki/L-DOPA
# /wiki/Substituted_phenethylamine
# /wiki/2C-T-21
# /wiki/Sumatriptan
# /wiki/Amitriptyline
# /wiki/Ketanserin
# /wiki/Hydroxybupropion
# /wiki/Mepyramine
# /wiki/UR-AK49
# /wiki/Adiponectin_receptor
# /wiki/Calcitonin
# /wiki/TMPRSS2
# /wiki/PubMed_Identifier
# /wiki/De-identification
# /wiki/Personalized_medicine
# /wiki/Surgery
# /wiki/Epicanthoplasty
# /wiki/Optical_coherence_tomography
# /wiki/Lens_(anatomy)
# /wiki/International_Standard_Book_Number
# /wiki/ISO/IEC_8859-12
# /wiki/Film_speed
# /wiki/O-ring
# /wiki/ISO_10161
# /wiki/Interlibrary_loan
# /wiki/Courier_service
# /wiki/Alipay_(payment_platform)
# /wiki/Tappr
# /wiki/Archive.is
# /wiki/WebCite
# /wiki/PubMed_Central
# /wiki/Life_sciences
# /wiki/Pharmacology
# /wiki/Partial_agonist
# /wiki/Drug_discovery
# /wiki/PubMed_Central
# /wiki/British_Library
# /wiki/Tauchnitz#The_Todd-Bowden_Collection_of_Tauchnitz_Editions
# /wiki/King%27s_manuscripts,_British_Library
# /wiki/British_Library_Philatelic_Department_Photograph_Collection
# /wiki/McInroy_Collection
# /wiki/Board_of_Inland_Revenue_Stamping_Department_Archive
# /wiki/American_Colonies
# /wiki/Colony_of_Rhode_Island_and_Providence_Plantations
# /wiki/William_Coddington
# /wiki/Joseph_Jenckes_(governor)
# /wiki/William_Wanton
# /wiki/Samuel_Ward_(American_statesman)
# /wiki/Nicholas_Cooke
# /wiki/Deputy_Governor_of_the_Colony_of_Rhode_Island_and_Providence_Plantations
# /wiki/Lieutenant_Governor_of_Maine
# /wiki/Boyd_Rutherford
# /wiki/Incumbent
# /wiki/Barcelona_Open_(tennis)
# /wiki/Spain
# /wiki/Monarchy_of_Spain
# /wiki/Order_of_Charles_III
# /wiki/List_of_Spanish_monarchs
# /wiki/Spanish_language
# /wiki/United_Nations
# /wiki/International_Year_of_Disabled_Persons
# /wiki/United_Nations
# /wiki/Hitlerism
# /wiki/Abba_Achimeir
# /wiki/International_Standard_Name_Identifier
# /wiki/ISO_15924
# /wiki/Mathematical_notation
# /wiki/Expression_(mathematics)
# /wiki/Rational_fraction
# /wiki/Rational_number
# /wiki/Additive_inverse
# /wiki/Negative_number
# /wiki/Plus_and_minus_signs
# /wiki/Venice
# /wiki/Isola_di_San_Secondo
# /wiki/Venice
# /wiki/Renaissance
# /wiki/Gr%C3%A3o_Vasco
# /wiki/International_Standard_Name_Identifier
# /wiki/International_Standard_Serial_Number
# /wiki/ISO/IEC_21827
# /wiki/ISO_9660
# /wiki/Extended_file_attributes
# /wiki/Filename_mangling
# /wiki/Microsoft_Windows
# /wiki/Linux
# /wiki/Linux_Gazette
# /wiki/Comparison_of_netbook-oriented_Linux_distributions
# /wiki/Sony_VAIO_M_series
# /wiki/Doel_(computer)
# /wiki/Samsung_Z2
# /wiki/Samsung_SGH-M310
# /wiki/Samsung_SCH-U940
# /wiki/Samsung_SPH-N270
# /wiki/The_Matrix
# /wiki/Judaism
# /wiki/Atheism
# /wiki/Tumbuka_mythology
# /wiki/International_Standard_Book_Number
# /wiki/Standard_Generalized_Markup_Language
# /wiki/ISO_19136
# /wiki/ISO/IEC_5218
# /wiki/XML_Metadata_Interchange
# /wiki/Business_Process_Model_and_Notation
# /wiki/Equal-loudness_contour
# /wiki/Universal_Coded_Character_Set
# /wiki/Guidelines_for_the_Definition_of_Managed_Objects
# /wiki/ISO_361
# /wiki/ISO/TR_11941
# /wiki/SKATS
# /wiki/Idu_script
# /wiki/Refreshable_braille_display
# /wiki/Mountbatten_Brailler
# /wiki/Vietnamese_Braille
# /wiki/New_York_Point
# /wiki/Syllabary
# /wiki/Tai_Tham_alphabet
# /wiki/Shavian_alphabet
# /wiki/Prachalit_Nepal_alphabet
# /wiki/List_of_inventors_of_writing_systems
# /wiki/Cuneiform
# /wiki/Babylonia
# /wiki/Medes
# /wiki/Safavid_dynasty
# /wiki/Teimuraz_I_of_Kakheti
# /wiki/International_Standard_Book_Number
# /wiki/Springer_Verlag
# /wiki/Cinven
# /wiki/Private_equity_secondary_market
# /wiki/Institutional_investor
# /wiki/SICAV
# /wiki/Luxembourg
# /wiki/Economy_of_Sweden
# /wiki/Economy_of_Djibouti
# /wiki/Economy_of_Romania
# /wiki/Economy_of_Belgium
# /wiki/Economy_of_Burkina_Faso
# /wiki/Non-bank_financial_institution
# /wiki/Equity_(finance)
# /wiki/Constant_purchasing_power_accounting
# /wiki/Deflation
# /wiki/Greenback_(money)
# /wiki/Demand_Note
# /wiki/International_Standard_Book_Number
# /wiki/Publishing
# /wiki/Online_book
# /wiki/Online_newspaper
# /wiki/Newspaper
# /wiki/Newspaper_of_record
# /wiki/Finland
# /wiki/Catholic_Church
# /wiki/Palo_(religion)
# /wiki/Nganga
# /wiki/Nkondi
# /wiki/Nganga
# /wiki/Prehistoric_medicine
# /wiki/Digital_object_identifier
# /wiki/ISO_14031
# /wiki/ISO_4157
# /wiki/Graphical_Kernel_System
# /wiki/ISO_55000
# /wiki/ISO_2033
# /wiki/Code_page_1119
# /wiki/EBCDIC_8616
# /wiki/ASCII
# /wiki/9
# /wiki/376_(number)
# /wiki/146_(number)
# /wiki/361_(number)
# /wiki/749_(number)
# /wiki/Compass_and_straightedge
# /wiki/Algebraic_number
# /wiki/Ordinal_number
# /wiki/Alternative_set_theory
# /wiki/Positive_set_theory
# /wiki/Weakly_compact_cardinal
# /wiki/Tree_(set_theory)
# /wiki/K%C3%B6nig%27s_lemma
# /wiki/Low_basis_theorem
# /wiki/Digital_object_identifier
# /wiki/First_class_(computing)
# /wiki/Identifier
# /wiki/Title
# /wiki/Scandinavian_family_name_etymology#Norway
# /wiki/Magnusson_(disambiguation)
# /wiki/Emil_Magnusson
# /wiki/Athletics_at_the_1912_Summer_Olympics_%E2%80%93_Men%27s_two_handed_discus_throw
# /wiki/Emil_Magnusson
# /wiki/Athletics_at_the_1912_Summer_Olympics_%E2%80%93_Men%27s_two_handed_discus_throw
# /wiki/Athletics_at_the_1988_Summer_Olympics_%E2%80%93_Women%27s_discus_throw
# /wiki/Athletics_at_the_2000_Summer_Olympics_%E2%80%93_Women%27s_discus_throw
# /wiki/Australia_at_the_2000_Summer_Olympics
# /wiki/Sydney_Football_Stadium
# /wiki/Rugby_League_Tri-Nations
# /wiki/Jake_Webster
# /wiki/Michael_Shenton
# /wiki/Castleford_Tigers
# /wiki/Super_League_XII
# /wiki/2007_Wests_Tigers_season
# /wiki/Tim_Sheens
# /wiki/2013_Rugby_League_World_Cup
# /wiki/Tonga_national_rugby_league_team
# /wiki/Balkans_Cup_(rugby_league)
# /wiki/Denmark_national_rugby_league_team
# /wiki/Lebanon_national_rugby_league_team
# /wiki/Rugby_League_European_Cup
# /wiki/1946-47_European_Rugby_League_Championship
# /wiki/Germany_national_rugby_league_team
# /wiki/Heidelberg
# /wiki/Robert_Bunsen
# /wiki/Adolf_von_Baeyer
# /wiki/Carl_Bosch
# /wiki/Richard_Adolf_Zsigmondy
# /wiki/John_Pople
# /wiki/Pople_diagram
# /wiki/Digital_object_identifier
# /wiki/Graphical_Kernel_System
# /wiki/ISO/IEC_8859-11
# /wiki/EBCDIC_033
# /wiki/Full_stop
# /wiki/Cambodian_riel
# /wiki/French_franc
# /wiki/Armenian_dram_sign
# /wiki/Indian_rupee_sign
# /wiki/IOS_7
# /wiki/ILife
# /wiki/Michael_Scott_(Apple)
# /wiki/Mike_Markkula
# /wiki/Avie_Tevanian
# /wiki/Paul_Deneve
# /wiki/Apple_Store
# /wiki/ZDNet
# /wiki/Amazing_Stories
# /wiki/Fantasy
# /wiki/Retrofuturism
# /wiki/We_Happy_Few_(video_game)
# /wiki/Measles
# /wiki/International_Statistical_Classification_of_Diseases_and_Related_Health_Problems
# /wiki/Description_logic
# /wiki/Epistemic_modal_logic
# /wiki/Stanford_Encyclopedia_of_Philosophy
# /wiki/Lane_Medical_Library
# /wiki/Stanford_Shopping_Center
# /wiki/The_Oaks_(Thousand_Oaks,_California)
# /wiki/Puente_Hills_Mall
# /wiki/Imperial_Valley_Mall
# /wiki/Gadsden_Mall
# /wiki/Decatur_Mall
# /wiki/Riverchase_Galleria
# /wiki/Fashion_Place
# /wiki/The_Shoppes_at_River_Crossing
# /wiki/Northeastern_United_States
# /wiki/National_Oceanic_and_Atmospheric_Administration
# ...
# /wiki/Eulogio_Despujol
# /wiki/Carlos_Mar%C3%ADa_de_la_Torre_y_Nava_Cerrada
# /wiki/Diego_Fajardo_Chac%C3%B3n
# /wiki/Ternate
# /wiki/Sultanate_of_Ternate
# /wiki/Safi,_Morocco
# /wiki/Kh%C3%A9nifra_Province
# /wiki/Moulay_Bouazza
# /wiki/Beni_Mellal
# /wiki/Virtual_International_Authority_File
# /wiki/Japanese_language
# /wiki/Chinese_characters
# /wiki/Wang_Xizhi
# /wiki/National_Library_of_Latvia
# /wiki/International_Standard_Book_Number
# /wiki/MPEG-4_Part_12
# /wiki/Dynamic_Resolution_Adaptation
# /wiki/Sorenson_Media
# /wiki/Super_Audio_CD#DST
# /wiki/Digital_Audio_Stationary_Head
# /wiki/Audio_mastering
# /wiki/Tape_loop
# /wiki/Psychedelic_music
# /wiki/Muzak
# /wiki/Austin,_Texas
# /wiki/Brushy_Creek,_Texas
# /wiki/Jarrell,_Texas
# /wiki/North_American_Central_Time_Zone
# /wiki/Normal,_Illinois
# /wiki/Ralph_Eugene_Meatyard
# /wiki/Guy_Davenport
# /wiki/Ralph_Eugene_Meatyard
# /wiki/Fourth_of_July
# /wiki/Cesar_Chavez_Day
# /wiki/List_of_observances_in_the_United_States_by_presidential_proclamation
# /wiki/Cancer_Control_Month
# /wiki/Courir_de_Mardi_Gras
# /wiki/Black_Friday_(shopping)
# /wiki/Christmas_in_Puritan_New_England
# /wiki/Flight_into_Egypt
# /wiki/Mary,_mother_of_Jesus
# /wiki/International_Standard_Book_Number
# /wiki/ISO/IEC_27006
# /wiki/ISO_31-0
# /wiki/ISO_1413
# /wiki/Common_Object_Request_Broker_Architecture
# /wiki/ISO/IEC_27006
# /wiki/ISO_860
# /wiki/ISO_28000
# /wiki/Ruby_(programming_language)
# /wiki/COBOL
# /wiki/Computerworld
# /wiki/Framingham,_Massachusetts
# /wiki/Norton,_Massachusetts
# /wiki/Bedford,_Massachusetts
# /wiki/North_Kingstown,_Rhode_Island
# /wiki/Bridgewater,_Massachusetts
# /wiki/Geographic_Names_Information_System
# /wiki/Gazetteer
# /wiki/Diodorus_Siculus
# /wiki/BIBSYS
# /wiki/Aftenposten
# /wiki/Adresseavisen
# /wiki/Newspaper_circulation
# /wiki/Daily_Sports
# /wiki/J%C5%8Dm%C5%8D_Shimbun
# /wiki/Journalist
# /wiki/Stringer_(journalism)
# /wiki/Fixer_(journalism)
# /wiki/Contributing_editor
# /wiki/Websites
# /wiki/Facebook
# /wiki/FactCheck.org
# /wiki/Annenberg_Public_Policy_Center
# /wiki/University_of_Pennsylvania_Campus_Historic_District
# /wiki/National_Register_of_Historic_Places_property_types
# /wiki/House
# /wiki/Dwelling
# /wiki/Runaway_(dependent)
# /wiki/Dysfunctional_family
# /wiki/Uncle
# /wiki/Polish_language
# /wiki/Proto-Slavic
# /wiki/Ogam
# /wiki/Neopagan
# /wiki/Wiccan
# /wiki/Caucasian_neopaganism
# /wiki/Dievtur%C4%ABba
# /wiki/Christianization
# /wiki/Migration_Period
# /wiki/Late_antiquity
# /wiki/Gillian_Clark_(historian)
# /wiki/The_City_of_God_(book)
# /wiki/The_Devil
# /wiki/List_of_minor_biblical_figures#Hobab
# /wiki/Ahinadab
# /wiki/List_of_biblical_names_starting_with_A
# /wiki/Aiah
# /wiki/Ophrah
# /wiki/Bethel
# /wiki/Ai_(Canaan)
# /wiki/Et-Tell
# /wiki/Al-Tall_(disambiguation)
# /wiki/Al-Tall_District
# /wiki/Darbal
# /wiki/Rima,_Qatana
# /wiki/Al-Dreij
# /wiki/Al-Maqrousa
# /wiki/Ar-Ruhaybah
# /wiki/Al-Adnaniyah
# /wiki/Ain_al-Tinah
# /wiki/Al-Qutayfah
# /wiki/Al-Bilaliyah
# /wiki/Deir_al-Asafir
# /wiki/Kafr_Batna
# /wiki/Darayya
# /wiki/Hafeir_al-Fouqa
# /wiki/Maarat_Saidnaya
# /wiki/Ras_al-Maara
# /wiki/Zamalka
# /wiki/Qalaat_al-Jandal
# /wiki/Baqin
# /wiki/Ain_al-Tinah
# /wiki/Al-Taybah,_Rif_Dimashq_Governorate
# /wiki/Jamraya
# /wiki/Arbin,_Syria
# /wiki/Kherbet_al-Sawda
# /wiki/Kanaker,_Syria
# /wiki/Qatana
# /wiki/Al-Sabinah
# /wiki/Al-Qleiaah
# /wiki/Ras_al-Ayn,_Rif_Dimashq_Governorate
# /wiki/Hala,_Syria
# /wiki/Jaramana
# /wiki/Jdeidat_Yabous
# /wiki/Hosh_Bajed
# /wiki/Mazraat_Deir_al-Ashayer
# /wiki/Time_zone
# /wiki/Pennsylvania
# /wiki/List_of_U.S._state_animals
# /wiki/List_of_U.S._states_by_income
# /wiki/Minnesota
# /wiki/McLeod_County,_Minnesota
# /wiki/Arrowhead_Region
# /wiki/Southeast_Minnesota
# /wiki/Driftless_Area
# /wiki/Monona_County,_Iowa
# /wiki/Worth_County,_Iowa
# /wiki/Iowa_Democratic_Party
# /wiki/Iowa_Caucuses
# /wiki/United_States_presidential_elections_in_Missouri
# /wiki/Super_Tuesday
# /wiki/United_States_presidential_election,_2016
# /wiki/Gary_Johnson_presidential_campaign,_2016
# /wiki/2016_Libertarian_National_Convention
# /wiki/1900_Democratic_National_Convention
# /wiki/Alabama_Democratic_Party
# /wiki/Arizona_Democratic_Party
# /wiki/George_Frederick_Senner,_Jr.
# /wiki/Biographical_Directory_of_the_United_States_Congress
# /wiki/List_of_presidents_pro_tempore_of_the_United_States_Senate
# /wiki/New_Hampshire
# /wiki/Swift_River_(Bearcamp_River)
# /wiki/West_Branch_Little_Dead_Diamond_River
# /wiki/Topsham,_Maine
# /wiki/Norway,_Maine
# /wiki/West_Bethel,_Maine
# /wiki/Paris,_Maine
# /wiki/West_Branch_Dead_Diamond_River
# /wiki/Hebron,_Maine
# /wiki/UTC-4
# /wiki/Brazil
# /wiki/Social_apartheid_in_Brazil
# /wiki/Public_holidays_in_Brazil
# /wiki/Brazil
# /wiki/Union_of_South_American_Nations
# /wiki/Organization_of_American_States
# /wiki/Pacific_Alliance
# /wiki/World_Federation_of_Exchanges
# /wiki/Seychelles_Securities_Exchange_(Trop-X)
# /wiki/Bermuda_Stock_Exchange
# /wiki/Military_of_Bermuda
# /wiki/United_Kingdom
# /wiki/Poverty_in_the_United_Kingdom
# /wiki/Digital_object_identifier
# /wiki/ISO_13399
# /wiki/Enterprise_resource_planning
# /wiki/Business_judgment_rule
# /wiki/Sociology_of_law
# /wiki/Law_school
# /wiki/Wayback_Machine
# /wiki/Internet_Archive%27s_images_collection
# /wiki/Columbia_University
# /wiki/Pupin_Hall
# /wiki/National_Register_of_Historic_Places_listings_in_Yates_County,_New_York
# /wiki/Potter,_New_York
# /wiki/Rushville,_New_York
# /wiki/Border_City,_New_York
# /wiki/County_seat
# /wiki/Carroll_County,_Mississippi
# /wiki/Grenada_County,_Mississippi
# /wiki/Mississippi_Legislature
# /wiki/Ken_Morgan_(politician)
# /wiki/Tyrone_Ellis_(politician)
# /wiki/Willie_Perkins_Sr.
# /wiki/Edward_Blackmon_Jr.
# /wiki/Tyrone_Ellis_(politician)
# /wiki/Chuck_Middleton
# /wiki/Jeff_Smith_(Mississippi_politician)
# /wiki/J.P._Hughes_Jr.
# /wiki/University_of_Mississippi_School_of_Law
# /wiki/James_W._Kitchens
# /wiki/State_Treasurer_of_Mississippi
# /wiki/David_Lillard
# /wiki/Terry_Hayes_(politician)
# /wiki/Oregon_State_Treasurer
# /wiki/Virginia_State_Treasurer
# /wiki/Jody_Wagner
# /wiki/Ohio
# /wiki/Languages_of_the_United_States
# /wiki/Syrian
# /wiki/Syrians#CITEREFBadroDouaihyHaberYouhanna2013
# /wiki/Ottoman_Syria
# /wiki/Arabic_language
# /wiki/List_of_Arabic_dictionaries
# /wiki/Arabic_language
# /wiki/Arabic_phonology#Local_variations
# /wiki/English_language
# /wiki/International_Standard_Book_Number
# /wiki/ISO_16750
# /wiki/Meta-Object_Facility
# /wiki/ISO_31
# /wiki/Simple_feature_access
# /wiki/Ruby_(programming_language)
# /wiki/ISO/IEC_8859
# /wiki/Homoglyph
# /wiki/Tai_Tham_alphabet
# /wiki/Bulgarian_Braille
# /wiki/Braille_technology
# /wiki/Vibratese
# /wiki/Pau_Cin_Hau_script
# /wiki/Tedim_language
# /wiki/Meithei_language
# /wiki/Kiranti_languages
# /wiki/Myanmar
# /wiki/Antelope
# /wiki/Sitatunga
# /wiki/Black-fronted_duiker
# /wiki/Okapi
# /wiki/Sharpe%27s_grysbok
# /wiki/Markhor
# /wiki/African_buffalo
# /wiki/Antilopinae
# /wiki/Cuvier%27s_gazelle
# /wiki/Dall_sheep
# /wiki/Northwestern_wolf
# /wiki/British_Columbia
# /wiki/List_of_First_Nations_governments_in_British_Columbia
# /wiki/Carrier_Sekani_Tribal_Council
# /wiki/Wet%27suwet%27en_First_Nation
# /wiki/Saik%27uz_First_Nation
# /wiki/Stellat%27en_First_Nation
# /wiki/Saik%27uz_First_Nation
# /wiki/Moricetown_Indian_Band
# /wiki/Moricetown,_British_Columbia
# /wiki/Bulkley_River
# /wiki/Russian_American_Telegraph
# /wiki/Radio_network
# /wiki/Southern_Star_(radio)
# /wiki/Blenheim,_New_Zealand
# /wiki/Namesake
# /wiki/F%C3%A9dora
# /wiki/Edward_Jos%C3%A9
# /wiki/Anna_Karenina_(1915_film)
# /wiki/Romeo_and_Juliet_(1916_Fox_film)
# /wiki/Butterfly_Lovers
# /wiki/China_Television
# /wiki/TVBS-Asia
# /wiki/HBO_(Asia)
# /wiki/HBO_Go
# /wiki/Otter_Media
# /wiki/CNNMoney
# /wiki/Turner_Classic_Movies_(UK_and_Ireland)
# /wiki/Boomerang_(TV_channel)
# /wiki/DC_Animated_Universe
# /wiki/DreamWorks_Animation
# /wiki/20th_Century_Fox
# /wiki/Fox_Television_Stations
# /wiki/The_CW
# /wiki/Max_Headroom_(TV_series)
# /wiki/W._Morgan_Sheppard
# /wiki/The_Long,_Twilight_Struggle
# /wiki/In_the_Shadow_of_Z%27ha%27dum
# /wiki/Morden_(Babylon_5)
# /wiki/Babylon_5_Collectible_Card_Game
# /wiki/Crusade_(TV_series)
# /wiki/Lorien_(Babylon_5)
# /wiki/Laurel_Takashima
# /wiki/Minbari
# /wiki/Explorer_class_starship
# /wiki/Babylon_5
# /wiki/I_Am_the_Night_(TV_series)
# /wiki/Yul_Vazquez
# /wiki/The_Take_(2007_film)
# /wiki/Bobby_Cannavale
# /wiki/The_Station_Agent
# /wiki/Metacritic
# /wiki/KCNC-TV
# /wiki/WXTV-DT
# /wiki/KHOV-FM
# /wiki/KFZO
# /wiki/KAWA_(FM)
# /wiki/Christian_rock
# /wiki/Heavy_metal_music
# /wiki/W.A.S.P._(band)
# /wiki/R.E.M.
# /wiki/Lifes_Rich_Pageant
# /wiki/Cuyahoga_River
# /wiki/First_Ladies_National_Historic_Site
# /wiki/National_Register_of_Historic_Places_listings_in_Hawaii
# /wiki/Lihue,_Hawaii
# /wiki/Wayback_Machine
# /wiki/Bruce_Gilliat
# /wiki/California
# /wiki/Rain_shadow
# /wiki/Hindukush
# /wiki/Yorke_Peninsula
# /wiki/Minlaton,_South_Australia
# /wiki/Point_Pearce,_South_Australia
# /wiki/Yunyarinyi
# /wiki/Local_government_areas_of_South_Australia
# /wiki/Coober_Pedy,_South_Australia
# /wiki/Katherine,_Northern_Territory
# /wiki/Wet_season
# /wiki/Tropical_climate
# /wiki/Brazil
# /wiki/UNESCO
# /wiki/United_Nations_Economic_and_Social_Commission_for_Asia_and_the_Pacific
# /wiki/Japan
# /wiki/Shinz%C5%8D_Abe
# /wiki/New_York_Times
# /wiki/Nuclear_program_of_Iran
# /wiki/Uranium_dioxide
# /wiki/Chromium(IV)_oxide
# /wiki/Gallium(I)_oxide
# /wiki/Thorium_monoxide
# /wiki/Disulfur_dioxide
# /wiki/Digital_object_identifier
# /wiki/Persistent_Uniform_Resource_Locator
# /wiki/World_Wide_Web_Consortium
# /wiki/French_Institute_for_Research_in_Computer_Science_and_Automation
# /wiki/Bigloo
# /wiki/Software_categories#Categorization_approaches
# /wiki/Transportation_industry
# /wiki/Ecotourism
# /wiki/International_Standard_Book_Number
# /wiki/Bookend
# /wiki/Audiobook
# /wiki/International_Standard_Book_Number
# /wiki/ISO/TS_16949
# /wiki/ISO/IEC_6523
# /wiki/Whirlpool_(hash_function)
# /wiki/Standard_Generalized_Markup_Language
# /wiki/Pinyin
# /wiki/Voiceless_bilabial_stop
# /wiki/Voiced_dental_fricative
# /wiki/Voiceless_velar_fricative
# /wiki/Near-close_central_unrounded_vowel
# /wiki/Open-mid_back_rounded_vowel
# /wiki/Kaingang_language
# /wiki/Ikpeng_language
# /wiki/Kadiweu_language
# /wiki/Omagua_language
# /wiki/Taushiro_language
# /wiki/Indigenous_languages_of_the_Americas
# /wiki/International_Standard_Book_Number
# /wiki/ISO_13406-2
# /wiki/ISO_14971
# /wiki/RELAX_NG
# /wiki/Document_Style_Semantics_and_Specification_Language
# /wiki/Scheme_(programming_language)
# /wiki/Dynamic_typing
# /wiki/Type_theory
# /wiki/Mixed_reality
# /wiki/Famicom_3D_System
# /wiki/Virtual_reality
# /wiki/Model_of_computation
# /wiki/Abstract_machine
# /wiki/Instruction_set
# /wiki/Adiabatic_quantum_computing
# /wiki/Digital_object_identifier
# /wiki/Simple_feature_access
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ee18b17d20d4> in <module>()
#      15     newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      16     print(newArticle)
# ---> 17     links = getLinks(newArticle)
#
# <ipython-input-3-ee18b17d20d4> in getLinks(articleUrl)
#       7 random.seed(datetime.datetime.now())
#       8 def getLinks(articleUrl):
# ----> 9     html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
#      10     bs = BeautifulSoup(html, 'html.parser')
#      11     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        print(bs.find(id ='mw-content-text').find_all('p')[0])
        print(bs.find(id='ca-edit').find('span').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, includeUrl):
    includeUrl = '{}://{}'.format(urlparse(includeUrl).scheme, urlparse(includeUrl).netloc)
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bs.find_all('a', href=re.compile('^(/|.*'+includeUrl+')')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" that do
    #not contain the current URL
    for link in bs.find_all('a', href=re.compile('^(http|www)((?!'+excludeUrl+').)*$')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bs = BeautifulSoup(html, 'html.parser')
    externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print('No external links, looking around the site for one')
        domain = '{}://{}'.format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
        internalLinks = getInternalLinks(bs, domain)
        return getRandomExternalLink(internalLinks[random.randint(0,
                                    len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print('Random external link is: {}'.format(externalLink))
    followExternalOnly(externalLink)
            
followExternalOnly('http://oreilly.com')

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = set()
allIntLinks = set()


def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = '{}://{}'.format(urlparse(siteUrl).scheme,
                              urlparse(siteUrl).netloc)
    bs = BeautifulSoup(html, 'html.parser')
    internalLinks = getInternalLinks(bs, domain)
    externalLinks = getExternalLinks(bs, domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)


allIntLinks.add('http://oreilly.com')
getAllExternalLinks('http://oreilly.com')
